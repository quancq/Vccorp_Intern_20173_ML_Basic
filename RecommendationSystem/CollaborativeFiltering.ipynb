# %%
import os, time, math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import sparse
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import mean_squared_error

# %%
# Define path of dataset 100K
data_dir1 = "./Data/ml-100k"
ratings_train_path1 = os.path.join(data_dir1, "ua.base")
ratings_test_path1 = os.path.join(data_dir1, "ua.test")
items_file_path1 = os.path.join(data_dir1, "u.item")
users_file_path1 = os.path.join(data_dir1, "u.user")

# %%
# Read users file
u_cols1 =  ['userId', 'age', 'sex', 'occupation', 'zip_code']
users1 = pd.read_csv(users_file_path1, sep='|', names=u_cols1, encoding='latin-1')

n_users1 = users1.shape[0]
print("Number of users:", n_users1)
# Out:
# Number of users: 943

# %%
# Read ratings file
r_cols1 = ['userId', 'movieId', 'rating', 'unix_timestamp']

ratings_train1 = pd.read_csv(ratings_train_path1, sep='\t', names=r_cols1, encoding='latin-1')
ratings_test1 = pd.read_csv(ratings_test_path1, sep='\t', names=r_cols1, encoding='latin-1')

print("Training data size : ", ratings_train1.shape[0])
print("Test data size     : ", ratings_test1.shape[0])
# Out:
# Training data size :  90570
# Test data size     :  9430

# %%
#Reading items file:
i_cols1 = ['movieId', 'movie title' ,'release date','video release date', 'IMDb URL', 'unknown', 'Action', 'Adventure',
 'Animation', 'Children\'s', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Fantasy',
 'Film-Noir', 'Horror', 'Musical', 'Mystery', 'Romance', 'Sci-Fi', 'Thriller', 'War', 'Western']

items1 = pd.read_csv(items_file_path1, sep='|', names=i_cols1, encoding='latin-1')

n_items1 = items1.shape[0]
print("Number of items:", n_items1)
# Out:
# Number of items: 1682

# %%
def convert_genres_names(genres_names):
    genres_names = genres_names.replace("(no genres listed)", "Unknown")
    genres_names = genres_names.replace('|', ' ')
    genres_names = genres_names.replace('-', '')
    return genres_names

# %%
# Define path of dataset 1M
data_dir2 = "./Data/ml-1m"
ratings_file_path2 = os.path.join(data_dir2, "ratings.dat")
items_file_path2 = os.path.join(data_dir2, "movies.dat")
# ratings_path2 = os.path.join(data_dir2, "ratings.dat")
ratings_train_path2 = os.path.join(data_dir2, "ratings_train.csv")
ratings_test_path2 = os.path.join(data_dir2, "ratings_test.csv")

# %%
# Reading items file:
i_cols2 = ["movieId", "title", "genres"]
items2 = pd.read_csv(items_file_path2, encoding="latin-1", sep="::", names=i_cols2)

num_items2 = items2.shape[0]
print("Number of items (movies) : ", num_items2)
items2["genres"] = items2["genres"].apply(convert_genres_names)
# print(items.info())
print("Example items:")
items2.head(3)
# Out:
# Number of items (movies) :  3883
# Example items:
# /home/quanchu/.local/lib/python3.5/site-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until
#    movieId                    title                        genres
# 0        1         Toy Story (1995)   Animation Children's Comedy
# 1        2           Jumanji (1995)  Adventure Children's Fantasy
# 2        3  Grumpier Old Men (1995)                Comedy Romance

# %%
# # Read ratings file
# r_cols2 = ["userId", "movieId", "rating", "unix_timestamp"]
# ratings2 = pd.read_csv(ratings_file_path2, encoding="utf-8", sep="::", names=r_cols2)

# print("Info training data :"); print(ratings2.info())
# print("Example training data : \n")
# ratings2.head()
# Out:
# /home/quanchu/.local/lib/python3.5/site-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Info training data :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000209 entries, 0 to 1000208
# Data columns (total 4 columns):
# userId            1000209 non-null int64
# movieId           1000209 non-null int64
# rating            1000209 non-null int64
# unix_timestamp    1000209 non-null int64
# dtypes: int64(4)
# memory usage: 30.5 MB
# None
# Example training data :
#    userId  movieId  rating  unix_timestamp
# 0       1     1193       5       978300760
# 1       1      661       3       978302109
# 2       1      914       3       978301968
# 3       1     3408       4       978300275
# 4       1     2355       5       978824291

# %%
# from sklearn.model_selection import train_test_split
# # Split train test
# ratings_train, ratings_test = train_test_split(ratings, test_size=0.2, random_state=7)
# training_size = ratings_train.shape[0]
# test_size = ratings_test.shape[0]
# dataset_size = ratings.shape[0]
# print("Training data size : {}, pct = {:.2f}%%".format(training_size, training_size / dataset_size * 100))
# print("Test data size     : {}, pct = {:.2f}%%".format(test_size, test_size / dataset_size * 100))
# print("Dataset size       : {}".format(dataset_size))
# Out:
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# Training data size : 800167, pct = 80.00%%
# Test data size     : 200042, pct = 20.00%%
# Dataset size       : 1000209

# %%
# ratings_train.to_csv(ratings_train_path, index=False)
# ratings_test.to_csv(ratings_test_path, index=False)

# %%
ratings_train2 = pd.read_csv(ratings_train_path2, encoding="utf-8")
training_size2 = ratings_train2.shape[0]
print("Training data size : ", training_size2)
ratings_train2.head()
# Out:
# Training data size :  800167
#    userId  movieId  rating  unix_timestamp
# 0    1926       34       4       974692704
# 1    3173     1073       5       968791878
# 2    5175     2762       5       961861063
# 3    4835     3754       2       962895467
# 4    4626     2071       5       964114511

# %%
ratings_test2 = pd.read_csv(ratings_test_path2, encoding="utf-8")
test_size2 = ratings_test2.shape[0]
print("Test data size : ", test_size2)
ratings_test2.head()
# Out:
# Test data size :  200042
#    userId  movieId  rating  unix_timestamp
# 0    5972      593       5       956952291
# 1    5952     2401       4       957145342
# 2    4933     1805       2      1011684938
# 3    2181      587       2       975634724
# 4    2513     1641       5       974072036

# %%
# ratings_train_path = os.path.join(data_dir, "ratings_train.csv")
# ratings_test_path = os.path.join(data_dir, "ratings_test.csv")
# ratings_train.to_csv(ratings_train_path, encoding="utf-8", index=False)
# ratings_test.to_csv(ratings_test_path, encoding="utf-8", index=False)

# %%
# tags = pd.read_csv(tags_file_path, encoding="utf-8")
# num_tags = tags.shape[0]
# print("Num tags : ", num_tags)
# tags.head()
# Out:
# Num tags :  1128
#    tagId           tag
# 0      1           007
# 1      2  007 (series)
# 2      3  18th century
# 3      4         1920s
# 4      5         1930s

# %%
# genome_scores = pd.read_csv(genome_scores_file_path, encoding="utf-8")
# print("Number records : ", genome_scores.shape[0])
# genome_scores.head()
# Out:
# Number records :  11709768
#    movieId  tagId  relevance
# 0        1      1    0.02500
# 1        1      2    0.02500
# 2        1      3    0.05775
# 3        1      4    0.09675
# 4        1      5    0.14675

# %%
class CollaborativeFiltering():
    def __init__(self, ratings_train, dataset_name, k_nearest_neighbors = 10, sim_func=cosine_similarity, uuCF=True):
        self.uuCF = uuCF    # uuCF is True if user-user CF, is False if item-item
        self.ratings_train = ratings_train if uuCF else ratings_train[:, [1, 0, 2]]    # ndarray type
        self.dataset_name = dataset_name
        self.k_nearest_neighbors = k_nearest_neighbors
        self.sim_func = sim_func
        self.map_users_sim = {}
        self.algo_name = "User-User CF" if uuCF else "Item-Item CF"
        
    
    def build_map(self, ndarray):
        # Return map from old id to new id, vice versa and new ndarray contain new id
        unique_array = np.unique(ndarray)
        
        map_old_id_to_new = {}
        map_new_id_to_old = {}
        
        for i in range(unique_array.shape[0]):
            old_id = unique_array[i]
            map_old_id_to_new.update({old_id: i})
            map_new_id_to_old.update({i: old_id})
            
        new_ids = np.array([map_old_id_to_new.get(old_id) for old_id in ndarray])
        
        return new_ids, map_old_id_to_new, map_new_id_to_old
    
    def fit(self):
        # Build sparse similarity matrix
        
        self.ratings_train[:, 0], self.map_old_user_id_to_new, self.map_new_user_id_to_old = self.build_map(self.ratings_train[:, 0])
        self.ratings_train[:, 1], self.map_old_item_id_to_new, self.map_new_item_id_to_old = self.build_map(self.ratings_train[:, 1])
        
        self.num_users = len(self.map_old_user_id_to_new)
        self.num_items = len(self.map_old_item_id_to_new)
        print("Num users distinct : ", self.num_users)
        print("Num items distinct : ", self.num_items)

        self.sparse_sim_matrix = sparse.coo_matrix(
            (self.ratings_train[:, 2], (self.ratings_train[:, 0], self.ratings_train[:, 1])),
            (self.num_users, self.num_items))
        self.sparse_sim_matrix = self.sparse_sim_matrix.tocsr()
        print("{} fit done".format(self.algo_name))
    
    def calc_similarity(self, user_id1, user_id2):
        if user_id1 > user_id2:
            user_id1, user_id2 = user_id2, user_id1
        sim = self.map_users_sim.get((user_id1, user_id2))
        if sim is None: 
            features1 = self.sparse_sim_matrix[user_id1, :]
            features2 = self.sparse_sim_matrix[user_id2, :]
            sim = self.sim_func(features1, features2)
            self.map_users_sim.update({(user_id1, user_id2): sim})
        
        return sim
    
    def get_user_rated_item(self, item_id):
        filter_record_ids = np.where(self.ratings_train[:, 1] == item_id)
        if len(filter_record_ids) == 0:
            return None, None
        rated_users = self.ratings_train[filter_record_ids[0], 0]
        ratings = self.ratings_train[filter_record_ids[0], 2]
        return rated_users, ratings 
                                  
    # Predict rating of given user_id for movie_id
    def predict_rating(self, user_id, item_id, pct_in_batch=None):
        
        if self.uuCF is False:
            user_id, item_id = item_id, user_id
        
        # Convert to new id
        new_user_id = self.map_old_user_id_to_new.get(user_id)
        new_item_id = self.map_old_item_id_to_new.get(item_id)
        
#         print("Old user : {}, New user : {}, Old item : {}, New item : {}".format(user_id, new_user_id, item_id, new_item_id))
        
        # Check if user_id or item_id doesnt exist in training utility matrix
        if new_user_id is not None and new_item_id is not None:
            rated_users, ratings = self.get_user_rated_item(new_item_id)
            similarity = np.empty_like(ratings, dtype=np.float32)
            for i in range(len(similarity)):
                similarity[i] = self.calc_similarity(new_user_id, rated_users[i])
            pred_rating = np.sum(ratings * (similarity / (similarity.sum() + 1e-16)))
        else:
            rated_users = []
            if new_user_id is not None:
                # Pred_rating is mean of user's ratings in training data
                pred_rating = self.sparse_sim_matrix[new_user_id, :].mean()
            elif new_item_id is not None:
                # Pred_rating is mean of movie's ratings in training data
                pred_rating = self.sparse_sim_matrix[:, new_item_id].mean()
            else:
                # Pred_rating is mean of overall ratings in training data
                pred_rating = self.sparse_sim_matrix.mean()
        
        if pct_in_batch is None:
            print("UserID : {:8d}, MovieID : {:8d}, Number rated : {:5d}, Predict rating : {:.4f}".format(user_id, item_id, len(rated_users), pred_rating))
        else:
            print("{:6.2f}%  UserID : {:8d}, MovieID : {:8d}, Number rated : {:5d}, Predict rating : {:.4f}".format(pct_in_batch, user_id, item_id, len(rated_users), pred_rating))

        return pred_rating
    
    def predict_rating_batch(self, ids):
        # ids is list of (user_id, movie_id) tuple
        batch_size = len(ids)
        print("Predicting {} ratings ...".format(batch_size))
        pred_ratings = []
        for i in range(batch_size):
            user_id = ids[i][0]
            item_id = ids[i][1]
            pct_in_batch = (i + 1) / batch_size * 100
            pred_ratings.append(self.predict_rating(user_id, item_id, pct_in_batch))
        return np.array(pred_ratings)
    
    def get_rmse(self, true_ratings, pred_ratings):
        return math.sqrt(mean_squared_error(true_ratings, pred_ratings))
    
    def evaluate_model(self, test_data):
        start_time = time.time()

        ids = list(zip(list(test_data.userId.values), list(test_data.movieId.values)))
        pred_ratings = self.predict_rating_batch(ids)
        predicted_data = test_data.copy()
        predicted_data["Predict rating"] = pred_ratings
        true_ratings = test_data.rating.values
        rmse_error = self.get_rmse(true_ratings, pred_ratings)

        finish_time = time.time()
        exec_time = finish_time - start_time

        print("\nSize of evaluate data : ", test_data.shape[0])
        print("Time : {} seconds".format(exec_time))
        print("RMSE : ", rmse_error)

        return predicted_data, rmse_error, exec_time

# %%
rs1 = CollaborativeFiltering(ratings_train1.iloc[:, :3].values, "ml-100k", uuCF=False)
rs1.fit()
# Out:
# Num users distinct :  1680
# Num items distinct :  943
# Item-Item CF fit done

# %%
predicted_data1, rmse_test_error1, exec_time1 = rs1.evaluate_model(ratings_test1)
# Out:
# Predicting 9430 ratings ...
#   0.01%  UserID :       20, MovieID :        1, Number rated :   262, Predict rating : 3.9285
#   0.02%  UserID :       33, MovieID :        1, Number rated :   262, Predict rating : 3.6977
#   0.03%  UserID :       61, MovieID :        1, Number rated :   262, Predict rating : 3.9329
#   0.04%  UserID :      117, MovieID :        1, Number rated :   262, Predict rating : 3.7095
#   0.05%  UserID :      155, MovieID :        1, Number rated :   262, Predict rating : 3.6429
#   0.06%  UserID :      160, MovieID :        1, Number rated :   262, Predict rating : 3.8002
#   0.07%  UserID :      171, MovieID :        1, Number rated :   262, Predict rating : 3.9070
#   0.08%  UserID :      189, MovieID :        1, Number rated :   262, Predict rating : 3.8383
#   0.10%  UserID :      202, MovieID :        1, Number rated :   262, Predict rating : 3.7439
#   0.11%  UserID :      265, MovieID :        1, Number rated :   262, Predict rating : 3.7233
#   0.12%  UserID :       13, MovieID :        2, Number rated :    52, Predict rating : 3.8585
#   0.13%  UserID :       50, MovieID :        2, Number rated :    52, Predict rating : 3.8478
#   0.14%  UserID :      251, MovieID :        2, Number rated :    52, Predict rating : 3.8554
#   0.15%  UserID :      280, MovieID :        2, Number rated :    52, Predict rating : 3.7870
#   0.16%  UserID :      281, MovieID :        2, Number rated :    52, Predict rating : 3.8147
#   0.17%  UserID :      290, MovieID :        2, Number rated :    52, Predict rating : 3.7936
#   0.18%  UserID :      292, MovieID :        2, Number rated :    52, Predict rating : 3.7991
#   0.19%  UserID :      297, MovieID :        2, Number rated :    52, Predict rating : 3.8648
#   0.20%  UserID :      312, MovieID :        2, Number rated :    52, Predict rating : 3.8348
#   0.21%  UserID :      314, MovieID :        2, Number rated :    52, Predict rating : 3.7664
#   0.22%  UserID :      245, MovieID :        3, Number rated :    44, Predict rating : 2.8739
#   0.23%  UserID :      294, MovieID :        3, Number rated :    44, Predict rating : 2.8936
#   0.24%  UserID :      323, MovieID :        3, Number rated :    44, Predict rating : 2.8595
#   0.25%  UserID :      328, MovieID :        3, Number rated :    44, Predict rating : 2.8979
#   0.27%  UserID :      331, MovieID :        3, Number rated :    44, Predict rating : 2.8973
#   0.28%  UserID :      332, MovieID :        3, Number rated :    44, Predict rating : 2.8948
#   0.29%  UserID :      334, MovieID :        3, Number rated :    44, Predict rating : 2.8556
#   0.30%  UserID :      335, MovieID :        3, Number rated :    44, Predict rating : 2.8338
#   0.31%  UserID :      337, MovieID :        3, Number rated :    44, Predict rating : 2.9268
#   0.32%  UserID :      343, MovieID :        3, Number rated :    44, Predict rating : 2.9211
#   0.33%  UserID :       50, MovieID :        4, Number rated :    14, Predict rating : 4.0978
#   0.34%  UserID :      260, MovieID :        4, Number rated :    14, Predict rating : 4.2188
#   0.35%  UserID :      264, MovieID :        4, Number rated :    14, Predict rating : 4.2379
#   0.36%  UserID :      288, MovieID :        4, Number rated :    14, Predict rating : 4.2026
#   0.37%  UserID :      294, MovieID :        4, Number rated :    14, Predict rating : 4.1612
#   0.38%  UserID :      303, MovieID :        4, Number rated :    14, Predict rating : 4.4357
#   0.39%  UserID :      354, MovieID :        4, Number rated :    14, Predict rating : 4.2301
#   0.40%  UserID :      356, MovieID :        4, Number rated :    14, Predict rating : 4.0559
#   0.41%  UserID :      357, MovieID :        4, Number rated :    14, Predict rating : 4.1078
#   0.42%  UserID :      361, MovieID :        4, Number rated :    14, Predict rating : 4.5303
#   0.43%  UserID :        1, MovieID :        5, Number rated :   165, Predict rating : 3.1425
#   0.45%  UserID :        2, MovieID :        5, Number rated :   165, Predict rating : 3.0810
#   0.46%  UserID :       17, MovieID :        5, Number rated :   165, Predict rating : 3.1078
#   0.47%  UserID :       98, MovieID :        5, Number rated :   165, Predict rating : 3.1424
#   0.48%  UserID :      110, MovieID :        5, Number rated :   165, Predict rating : 2.8559
#   0.49%  UserID :      225, MovieID :        5, Number rated :   165, Predict rating : 2.9497
#   0.50%  UserID :      363, MovieID :        5, Number rated :   165, Predict rating : 3.0103
#   0.51%  UserID :      424, MovieID :        5, Number rated :   165, Predict rating : 2.7543
#   0.52%  UserID :      439, MovieID :        5, Number rated :   165, Predict rating : 2.4499
#   0.53%  UserID :      454, MovieID :        5, Number rated :   165, Predict rating : 2.9470
#   0.54%  UserID :       14, MovieID :        6, Number rated :   201, Predict rating : 3.7221
#   0.55%  UserID :       23, MovieID :        6, Number rated :   201, Predict rating : 3.7968
#   0.56%  UserID :       69, MovieID :        6, Number rated :   201, Predict rating : 3.6776
#   0.57%  UserID :       86, MovieID :        6, Number rated :   201, Predict rating : 3.7641
#   0.58%  UserID :       98, MovieID :        6, Number rated :   201, Predict rating : 3.7022
#   0.59%  UserID :      258, MovieID :        6, Number rated :   201, Predict rating : 3.5676
#   0.60%  UserID :      301, MovieID :        6, Number rated :   201, Predict rating : 3.5595
#   0.62%  UserID :      463, MovieID :        6, Number rated :   201, Predict rating : 3.7688
#   0.63%  UserID :      492, MovieID :        6, Number rated :   201, Predict rating : 3.8711
#   0.64%  UserID :      517, MovieID :        6, Number rated :   201, Predict rating : 3.8482
#   0.65%  UserID :       32, MovieID :        7, Number rated :   393, Predict rating : 4.1501
#   0.66%  UserID :      163, MovieID :        7, Number rated :   393, Predict rating : 4.1476
#   0.67%  UserID :      382, MovieID :        7, Number rated :   393, Predict rating : 4.1013
#   0.68%  UserID :      430, MovieID :        7, Number rated :   393, Predict rating : 4.1685
#   0.69%  UserID :      455, MovieID :        7, Number rated :   393, Predict rating : 4.0407
#   0.70%  UserID :      479, MovieID :        7, Number rated :   393, Predict rating : 4.1583
#   0.71%  UserID :      492, MovieID :        7, Number rated :   393, Predict rating : 4.2167
#   0.72%  UserID :      497, MovieID :        7, Number rated :   393, Predict rating : 4.1770
#   0.73%  UserID :      648, MovieID :        7, Number rated :   393, Predict rating : 4.1895
#   0.74%  UserID :      661, MovieID :        7, Number rated :   393, Predict rating : 4.2041
#   0.75%  UserID :       22, MovieID :        8, Number rated :    49, Predict rating : 4.1347
#   0.76%  UserID :       50, MovieID :        8, Number rated :    49, Predict rating : 4.1451
#   0.77%  UserID :       79, MovieID :        8, Number rated :    49, Predict rating : 4.1668
#   0.78%  UserID :       89, MovieID :        8, Number rated :    49, Predict rating : 4.1819
#   0.80%  UserID :      182, MovieID :        8, Number rated :    49, Predict rating : 4.1674
#   0.81%  UserID :      294, MovieID :        8, Number rated :    49, Predict rating : 3.9984
#   0.82%  UserID :      338, MovieID :        8, Number rated :    49, Predict rating : 3.8295
#   0.83%  UserID :      385, MovieID :        8, Number rated :    49, Predict rating : 4.1469
#   0.84%  UserID :      457, MovieID :        8, Number rated :    49, Predict rating : 3.6648
#   0.85%  UserID :      550, MovieID :        8, Number rated :    49, Predict rating : 4.1220
#   0.86%  UserID :        6, MovieID :        9, Number rated :    12, Predict rating : 4.0697
#   0.87%  UserID :      286, MovieID :        9, Number rated :    12, Predict rating : 4.1211
#   0.88%  UserID :      298, MovieID :        9, Number rated :    12, Predict rating : 4.2906
#   0.89%  UserID :      340, MovieID :        9, Number rated :    12, Predict rating : 4.0692
#   0.90%  UserID :      479, MovieID :        9, Number rated :    12, Predict rating : 4.4181
#   0.91%  UserID :      487, MovieID :        9, Number rated :    12, Predict rating : 4.3899
#   0.92%  UserID :      507, MovieID :        9, Number rated :    12, Predict rating : 4.4363
#   0.93%  UserID :      521, MovieID :        9, Number rated :    12, Predict rating : 4.4298
#   0.94%  UserID :      527, MovieID :        9, Number rated :    12, Predict rating : 4.3968
#   0.95%  UserID :      691, MovieID :        9, Number rated :    12, Predict rating : 3.5287
#   0.97%  UserID :        7, MovieID :       10, Number rated :   174, Predict rating : 4.2323
#   0.98%  UserID :       16, MovieID :       10, Number rated :   174, Predict rating : 4.1880
#   0.99%  UserID :      100, MovieID :       10, Number rated :   174, Predict rating : 4.2434
#   1.00%  UserID :      175, MovieID :       10, Number rated :   174, Predict rating : 4.2506
#   1.01%  UserID :      285, MovieID :       10, Number rated :   174, Predict rating : 4.2200
#   1.02%  UserID :      461, MovieID :       10, Number rated :   174, Predict rating : 4.2284
#   1.03%  UserID :      486, MovieID :       10, Number rated :   174, Predict rating : 4.2751
#   1.04%  UserID :      488, MovieID :       10, Number rated :   174, Predict rating : 4.2726
#   1.05%  UserID :      504, MovieID :       10, Number rated :   174, Predict rating : 4.2753
#   1.06%  UserID :      611, MovieID :       10, Number rated :   174, Predict rating : 4.2788
#   1.07%  UserID :       38, MovieID :       11, Number rated :   171, Predict rating : 3.3995
#   1.08%  UserID :      110, MovieID :       11, Number rated :   171, Predict rating : 3.3983
#   1.09%  UserID :      111, MovieID :       11, Number rated :   171, Predict rating : 3.4914
#   1.10%  UserID :      227, MovieID :       11, Number rated :   171, Predict rating : 3.4266
#   1.11%  UserID :      425, MovieID :       11, Number rated :   171, Predict rating : 3.4977
#   1.12%  UserID :      558, MovieID :       11, Number rated :   171, Predict rating : 3.4947
#   1.13%  UserID :      723, MovieID :       11, Number rated :   171, Predict rating : 3.4496
#   1.15%  UserID :      725, MovieID :       11, Number rated :   171, Predict rating : 3.3114
#   1.16%  UserID :      732, MovieID :       11, Number rated :   171, Predict rating : 3.4652
#   1.17%  UserID :      740, MovieID :       11, Number rated :   171, Predict rating : 3.5507
#   1.18%  UserID :       82, MovieID :       12, Number rated :    41, Predict rating : 4.3676
#   1.19%  UserID :       96, MovieID :       12, Number rated :    41, Predict rating : 4.3630
#   1.20%  UserID :       97, MovieID :       12, Number rated :    41, Predict rating : 4.3752
#   1.21%  UserID :      132, MovieID :       12, Number rated :    41, Predict rating : 4.3414
#   1.22%  UserID :      143, MovieID :       12, Number rated :    41, Predict rating : 4.3761
#   1.23%  UserID :      172, MovieID :       12, Number rated :    41, Predict rating : 4.3629
#   1.24%  UserID :      204, MovieID :       12, Number rated :    41, Predict rating : 4.3786
#   1.25%  UserID :      300, MovieID :       12, Number rated :    41, Predict rating : 4.3913
#   1.26%  UserID :      471, MovieID :       12, Number rated :    41, Predict rating : 4.4085
#   1.27%  UserID :      735, MovieID :       12, Number rated :    41, Predict rating : 4.3814
#   1.28%  UserID :       56, MovieID :       13, Number rated :   626, Predict rating : 3.3545
#   1.29%  UserID :       98, MovieID :       13, Number rated :   626, Predict rating : 3.3621
#   1.30%  UserID :      186, MovieID :       13, Number rated :   626, Predict rating : 3.3949
#   1.31%  UserID :      198, MovieID :       13, Number rated :   626, Predict rating : 3.4285
#   1.33%  UserID :      215, MovieID :       13, Number rated :   626, Predict rating : 3.3721
#   1.34%  UserID :      272, MovieID :       13, Number rated :   626, Predict rating : 3.2844
#   1.35%  UserID :      344, MovieID :       13, Number rated :   626, Predict rating : 3.2742
#   1.36%  UserID :      360, MovieID :       13, Number rated :   626, Predict rating : 2.5514
#   1.37%  UserID :      526, MovieID :       13, Number rated :   626, Predict rating : 3.4756
#   1.38%  UserID :      836, MovieID :       13, Number rated :   626, Predict rating : 3.6303
#   1.39%  UserID :       22, MovieID :       14, Number rated :    88, Predict rating : 4.1328
#   1.40%  UserID :       98, MovieID :       14, Number rated :    88, Predict rating : 4.1483
#   1.41%  UserID :      111, MovieID :       14, Number rated :    88, Predict rating : 4.0748
#   1.42%  UserID :      174, MovieID :       14, Number rated :    88, Predict rating : 4.1497
#   1.43%  UserID :      213, MovieID :       14, Number rated :    88, Predict rating : 4.1721
#   1.44%  UserID :      269, MovieID :       14, Number rated :    88, Predict rating : 4.1087
#   1.45%  UserID :      357, MovieID :       14, Number rated :    88, Predict rating : 4.1705
#   1.46%  UserID :      474, MovieID :       14, Number rated :    88, Predict rating : 4.2158
#   1.47%  UserID :      530, MovieID :       14, Number rated :    88, Predict rating : 4.2387
#   1.48%  UserID :      709, MovieID :       14, Number rated :    88, Predict rating : 4.1847
#   1.50%  UserID :       25, MovieID :       15, Number rated :    94, Predict rating : 2.9026
#   1.51%  UserID :      127, MovieID :       15, Number rated :    94, Predict rating : 2.9559
#   1.52%  UserID :      222, MovieID :       15, Number rated :    94, Predict rating : 2.8644
#   1.53%  UserID :      331, MovieID :       15, Number rated :    94, Predict rating : 2.9755
#   1.54%  UserID :      405, MovieID :       15, Number rated :    94, Predict rating : 2.8356
#   1.55%  UserID :      473, MovieID :       15, Number rated :    94, Predict rating : 2.8655
#   1.56%  UserID :      678, MovieID :       15, Number rated :    94, Predict rating : 2.8432
#   1.57%  UserID :      685, MovieID :       15, Number rated :    94, Predict rating : 2.8057
#   1.58%  UserID :      749, MovieID :       15, Number rated :    94, Predict rating : 3.0006
#   1.59%  UserID :      932, MovieID :       15, Number rated :    94, Predict rating : 2.7740
#   1.60%  UserID :        8, MovieID :       16, Number rated :   130, Predict rating : 4.4905
#   1.61%  UserID :       55, MovieID :       16, Number rated :   130, Predict rating : 4.4566
#   1.62%  UserID :       64, MovieID :       16, Number rated :   130, Predict rating : 4.4855
#   1.63%  UserID :       89, MovieID :       16, Number rated :   130, Predict rating : 4.5129
#   1.64%  UserID :      178, MovieID :       16, Number rated :   130, Predict rating : 4.5028
#   1.65%  UserID :      194, MovieID :       16, Number rated :   130, Predict rating : 4.5147
#   1.66%  UserID :      197, MovieID :       16, Number rated :   130, Predict rating : 4.5180
#   1.68%  UserID :      209, MovieID :       16, Number rated :   130, Predict rating : 4.4955
#   1.69%  UserID :      705, MovieID :       16, Number rated :   130, Predict rating : 4.5310
#   1.70%  UserID :      944, MovieID :       16, Number rated :   130, Predict rating : 4.3902
#   1.71%  UserID :        1, MovieID :       17, Number rated :    18, Predict rating : 3.2733
#   1.72%  UserID :        9, MovieID :       17, Number rated :    18, Predict rating : 3.2759
#   1.73%  UserID :       13, MovieID :       17, Number rated :    18, Predict rating : 3.4088
#   1.74%  UserID :      117, MovieID :       17, Number rated :    18, Predict rating : 3.2097
#   1.75%  UserID :      125, MovieID :       17, Number rated :    18, Predict rating : 3.1238
#   1.76%  UserID :      151, MovieID :       17, Number rated :    18, Predict rating : 3.2929
#   1.77%  UserID :      237, MovieID :       17, Number rated :    18, Predict rating : 3.2363
#   1.78%  UserID :      245, MovieID :       17, Number rated :    18, Predict rating : 3.0185
#   1.79%  UserID :      508, MovieID :       17, Number rated :    18, Predict rating : 3.3461
#   1.80%  UserID :      744, MovieID :       17, Number rated :    18, Predict rating : 3.3165
#   1.81%  UserID :       26, MovieID :       18, Number rated :   267, Predict rating : 3.8932
#   1.82%  UserID :       86, MovieID :       18, Number rated :   267, Predict rating : 3.9345
#   1.83%  UserID :      113, MovieID :       18, Number rated :   267, Predict rating : 4.0177
#   1.85%  UserID :      182, MovieID :       18, Number rated :   267, Predict rating : 3.8969
#   1.86%  UserID :      202, MovieID :       18, Number rated :   267, Predict rating : 3.8590
#   1.87%  UserID :      408, MovieID :       18, Number rated :   267, Predict rating : 3.9281
#   1.88%  UserID :      443, MovieID :       18, Number rated :   267, Predict rating : 3.8839
#   1.89%  UserID :      496, MovieID :       18, Number rated :   267, Predict rating : 3.8957
#   1.90%  UserID :      729, MovieID :       18, Number rated :   267, Predict rating : 3.8602
#   1.91%  UserID :      950, MovieID :       18, Number rated :   267, Predict rating : 3.9866
#   1.92%  UserID :        4, MovieID :       19, Number rated :    10, Predict rating : 3.6102
#   1.93%  UserID :      153, MovieID :       19, Number rated :    10, Predict rating : 3.6589
#   1.94%  UserID :      201, MovieID :       19, Number rated :    10, Predict rating : 3.5567
#   1.95%  UserID :      258, MovieID :       19, Number rated :    10, Predict rating : 3.4951
#   1.96%  UserID :      310, MovieID :       19, Number rated :    10, Predict rating : 3.4366
#   1.97%  UserID :      313, MovieID :       19, Number rated :    10, Predict rating : 3.5101
#   1.98%  UserID :      382, MovieID :       19, Number rated :    10, Predict rating : 3.6234
#   1.99%  UserID :      435, MovieID :       19, Number rated :    10, Predict rating : 3.6801
#   2.00%  UserID :      655, MovieID :       19, Number rated :    10, Predict rating : 3.5827
#   2.01%  UserID :      692, MovieID :       19, Number rated :    10, Predict rating : 3.6629
#   2.03%  UserID :       11, MovieID :       20, Number rated :    38, Predict rating : 3.2118
#   2.04%  UserID :      118, MovieID :       20, Number rated :    38, Predict rating : 3.2252
#   2.05%  UserID :      172, MovieID :       20, Number rated :    38, Predict rating : 3.2376
#   2.06%  UserID :      176, MovieID :       20, Number rated :    38, Predict rating : 3.2320
#   2.07%  UserID :      186, MovieID :       20, Number rated :    38, Predict rating : 3.2048
#   2.08%  UserID :      194, MovieID :       20, Number rated :    38, Predict rating : 3.2099
#   2.09%  UserID :      208, MovieID :       20, Number rated :    38, Predict rating : 3.1901
#   2.10%  UserID :      288, MovieID :       20, Number rated :    38, Predict rating : 3.2296
#   2.11%  UserID :      405, MovieID :       20, Number rated :    38, Predict rating : 3.2073
#   2.12%  UserID :      678, MovieID :       20, Number rated :    38, Predict rating : 3.2607
#   2.13%  UserID :      103, MovieID :       21, Number rated :   169, Predict rating : 2.8075
#   2.14%  UserID :      129, MovieID :       21, Number rated :   169, Predict rating : 3.1160
#   2.15%  UserID :      164, MovieID :       21, Number rated :   169, Predict rating : 2.9628
#   2.16%  UserID :      222, MovieID :       21, Number rated :   169, Predict rating : 2.9604
#   2.17%  UserID :      324, MovieID :       21, Number rated :   169, Predict rating : 2.9707
#   2.18%  UserID :      370, MovieID :       21, Number rated :   169, Predict rating : 2.6948
#   2.20%  UserID :      440, MovieID :       21, Number rated :   169, Predict rating : 2.6994
#   2.21%  UserID :      447, MovieID :       21, Number rated :   169, Predict rating : 3.0359
#   2.22%  UserID :      558, MovieID :       21, Number rated :   169, Predict rating : 3.1274
#   2.23%  UserID :      948, MovieID :       21, Number rated :   169, Predict rating : 2.7392
#   2.24%  UserID :       79, MovieID :       22, Number rated :   118, Predict rating : 3.6834
#   2.25%  UserID :       80, MovieID :       22, Number rated :   118, Predict rating : 3.5034
#   2.26%  UserID :      128, MovieID :       22, Number rated :   118, Predict rating : 3.5907
#   2.27%  UserID :      241, MovieID :       22, Number rated :   118, Predict rating : 3.6949
#   2.28%  UserID :      258, MovieID :       22, Number rated :   118, Predict rating : 3.6411
#   2.29%  UserID :      376, MovieID :       22, Number rated :   118, Predict rating : 3.3906
#   2.30%  UserID :      377, MovieID :       22, Number rated :   118, Predict rating : 2.9856
#   2.31%  UserID :      510, MovieID :       22, Number rated :   118, Predict rating : 3.7100
#   2.32%  UserID :      511, MovieID :       22, Number rated :   118, Predict rating : 3.8264
#   2.33%  UserID :      791, MovieID :       22, Number rated :   118, Predict rating : 3.3739
#   2.34%  UserID :      170, MovieID :       23, Number rated :   141, Predict rating : 3.7389
#   2.35%  UserID :      172, MovieID :       23, Number rated :   141, Predict rating : 3.6139
#   2.36%  UserID :      196, MovieID :       23, Number rated :   141, Predict rating : 3.6071
#   2.38%  UserID :      258, MovieID :       23, Number rated :   141, Predict rating : 3.6282
#   2.39%  UserID :      323, MovieID :       23, Number rated :   141, Predict rating : 3.5405
#   2.40%  UserID :      381, MovieID :       23, Number rated :   141, Predict rating : 3.6596
#   2.41%  UserID :      385, MovieID :       23, Number rated :   141, Predict rating : 3.5460
#   2.42%  UserID :      404, MovieID :       23, Number rated :   141, Predict rating : 3.5564
#   2.43%  UserID :      463, MovieID :       23, Number rated :   141, Predict rating : 3.7109
#   2.44%  UserID :     1006, MovieID :       23, Number rated :   141, Predict rating : 3.7521
#   2.45%  UserID :       64, MovieID :       24, Number rated :    58, Predict rating : 4.4208
#   2.46%  UserID :      129, MovieID :       24, Number rated :    58, Predict rating : 4.4041
#   2.47%  UserID :      153, MovieID :       24, Number rated :    58, Predict rating : 4.4241
#   2.48%  UserID :      191, MovieID :       24, Number rated :    58, Predict rating : 4.4090
#   2.49%  UserID :      367, MovieID :       24, Number rated :    58, Predict rating : 4.4113
#   2.50%  UserID :      372, MovieID :       24, Number rated :    58, Predict rating : 4.3927
#   2.51%  UserID :      427, MovieID :       24, Number rated :    58, Predict rating : 4.4163
#   2.52%  UserID :      662, MovieID :       24, Number rated :    58, Predict rating : 4.3616
#   2.53%  UserID :      742, MovieID :       24, Number rated :    58, Predict rating : 4.3636
#   2.55%  UserID :      763, MovieID :       24, Number rated :    58, Predict rating : 4.3764
#   2.56%  UserID :       25, MovieID :       25, Number rated :    68, Predict rating : 4.0300
#   2.57%  UserID :      181, MovieID :       25, Number rated :    68, Predict rating : 4.0270
#   2.58%  UserID :      208, MovieID :       25, Number rated :    68, Predict rating : 4.0018
#   2.59%  UserID :      222, MovieID :       25, Number rated :    68, Predict rating : 4.0402
#   2.60%  UserID :      228, MovieID :       25, Number rated :    68, Predict rating : 4.0127
#   2.61%  UserID :      257, MovieID :       25, Number rated :    68, Predict rating : 4.0457
#   2.62%  UserID :      258, MovieID :       25, Number rated :    68, Predict rating : 4.0448
#   2.63%  UserID :      357, MovieID :       25, Number rated :    68, Predict rating : 4.0054
#   2.64%  UserID :      501, MovieID :       25, Number rated :    68, Predict rating : 3.9614
#   2.65%  UserID :      615, MovieID :       25, Number rated :    68, Predict rating : 3.9913
#   2.66%  UserID :       15, MovieID :       26, Number rated :    97, Predict rating : 3.0226
#   2.67%  UserID :       25, MovieID :       26, Number rated :    97, Predict rating : 2.9834
#   2.68%  UserID :      125, MovieID :       26, Number rated :    97, Predict rating : 2.9477
#   2.69%  UserID :      235, MovieID :       26, Number rated :    97, Predict rating : 2.9451
#   2.70%  UserID :      258, MovieID :       26, Number rated :    97, Predict rating : 3.0345
#   2.71%  UserID :      455, MovieID :       26, Number rated :    97, Predict rating : 2.9253
#   2.73%  UserID :      685, MovieID :       26, Number rated :    97, Predict rating : 2.9180
#   2.74%  UserID :      930, MovieID :       26, Number rated :    97, Predict rating : 2.8441
#   2.75%  UserID :     1015, MovieID :       26, Number rated :    97, Predict rating : 3.0011
#   2.76%  UserID :     1016, MovieID :       26, Number rated :    97, Predict rating : 2.9382
#   2.77%  UserID :      121, MovieID :       27, Number rated :    15, Predict rating : 3.3890
#   2.78%  UserID :      246, MovieID :       27, Number rated :    15, Predict rating : 3.3896
#   2.79%  UserID :      281, MovieID :       27, Number rated :    15, Predict rating : 3.3707
#   2.80%  UserID :      298, MovieID :       27, Number rated :    15, Predict rating : 3.3580
#   2.81%  UserID :      370, MovieID :       27, Number rated :    15, Predict rating : 3.3000
#   2.82%  UserID :      475, MovieID :       27, Number rated :    15, Predict rating : 3.4566
#   2.83%  UserID :      596, MovieID :       27, Number rated :    15, Predict rating : 3.3647
#   2.84%  UserID :      742, MovieID :       27, Number rated :    15, Predict rating : 3.3947
#   2.85%  UserID :      925, MovieID :       27, Number rated :    15, Predict rating : 3.3465
#   2.86%  UserID :      978, MovieID :       27, Number rated :    15, Predict rating : 3.3013
#   2.87%  UserID :        7, MovieID :       28, Number rated :    69, Predict rating : 3.8406
#   2.88%  UserID :       79, MovieID :       28, Number rated :    69, Predict rating : 3.8350
#   2.90%  UserID :       95, MovieID :       28, Number rated :    69, Predict rating : 3.8038
#   2.91%  UserID :       98, MovieID :       28, Number rated :    69, Predict rating : 3.8343
#   2.92%  UserID :      173, MovieID :       28, Number rated :    69, Predict rating : 3.8391
#   2.93%  UserID :      201, MovieID :       28, Number rated :    69, Predict rating : 3.8513
#   2.94%  UserID :      209, MovieID :       28, Number rated :    69, Predict rating : 3.8651
#   2.95%  UserID :      217, MovieID :       28, Number rated :    69, Predict rating : 3.7686
#   2.96%  UserID :      234, MovieID :       28, Number rated :    69, Predict rating : 3.8125
#   2.97%  UserID :      380, MovieID :       28, Number rated :    69, Predict rating : 3.7629
#   2.98%  UserID :       98, MovieID :       29, Number rated :    24, Predict rating : 4.0352
#   2.99%  UserID :      189, MovieID :       29, Number rated :    24, Predict rating : 4.0802
#   3.00%  UserID :      245, MovieID :       29, Number rated :    24, Predict rating : 3.8274
#   3.01%  UserID :      332, MovieID :       29, Number rated :    24, Predict rating : 3.7933
#   3.02%  UserID :      358, MovieID :       29, Number rated :    24, Predict rating : 3.8234
#   3.03%  UserID :      539, MovieID :       29, Number rated :    24, Predict rating : 3.8401
#   3.04%  UserID :      678, MovieID :       29, Number rated :    24, Predict rating : 3.8113
#   3.05%  UserID :      689, MovieID :       29, Number rated :    24, Predict rating : 3.7630
#   3.06%  UserID :      748, MovieID :       29, Number rated :    24, Predict rating : 3.8182
#   3.08%  UserID :     1018, MovieID :       29, Number rated :    24, Predict rating : 4.1213
#   3.09%  UserID :       82, MovieID :       30, Number rated :    33, Predict rating : 3.8172
#   3.10%  UserID :      181, MovieID :       30, Number rated :    33, Predict rating : 3.8409
#   3.11%  UserID :      255, MovieID :       30, Number rated :    33, Predict rating : 3.8349
#   3.12%  UserID :      286, MovieID :       30, Number rated :    33, Predict rating : 3.9534
#   3.13%  UserID :      289, MovieID :       30, Number rated :    33, Predict rating : 3.8673
#   3.14%  UserID :      435, MovieID :       30, Number rated :    33, Predict rating : 3.9238
#   3.15%  UserID :      539, MovieID :       30, Number rated :    33, Predict rating : 3.7640
#   3.16%  UserID :      678, MovieID :       30, Number rated :    33, Predict rating : 3.7843
#   3.17%  UserID :      688, MovieID :       30, Number rated :    33, Predict rating : 3.8399
#   3.18%  UserID :     1007, MovieID :       30, Number rated :    33, Predict rating : 3.8836
#   3.19%  UserID :      135, MovieID :       31, Number rated :    26, Predict rating : 3.9342
#   3.20%  UserID :      302, MovieID :       31, Number rated :    26, Predict rating : 3.7588
#   3.21%  UserID :      321, MovieID :       31, Number rated :    26, Predict rating : 3.7769
#   3.22%  UserID :      484, MovieID :       31, Number rated :    26, Predict rating : 3.9435
#   3.23%  UserID :      493, MovieID :       31, Number rated :    26, Predict rating : 3.9408
#   3.24%  UserID :      498, MovieID :       31, Number rated :    26, Predict rating : 3.9231
#   3.26%  UserID :      504, MovieID :       31, Number rated :    26, Predict rating : 3.9201
#   3.27%  UserID :      682, MovieID :       31, Number rated :    26, Predict rating : 3.6297
#   3.28%  UserID :      705, MovieID :       31, Number rated :    26, Predict rating : 3.9056
#   3.29%  UserID :      886, MovieID :       31, Number rated :    26, Predict rating : 3.7406
#   3.30%  UserID :      117, MovieID :       32, Number rated :    31, Predict rating : 3.3254
#   3.31%  UserID :      151, MovieID :       32, Number rated :    31, Predict rating : 3.3655
#   3.32%  UserID :      246, MovieID :       32, Number rated :    31, Predict rating : 3.4407
#   3.33%  UserID :      249, MovieID :       32, Number rated :    31, Predict rating : 3.3092
#   3.34%  UserID :      250, MovieID :       32, Number rated :    31, Predict rating : 3.3100
#   3.35%  UserID :      276, MovieID :       32, Number rated :    31, Predict rating : 3.4018
#   3.36%  UserID :      290, MovieID :       32, Number rated :    31, Predict rating : 3.2818
#   3.37%  UserID :      294, MovieID :       32, Number rated :    31, Predict rating : 3.3052
#   3.38%  UserID :      591, MovieID :       32, Number rated :    31, Predict rating : 3.3505
#   3.39%  UserID :     1012, MovieID :       32, Number rated :    31, Predict rating : 3.3397
#   3.40%  UserID :      258, MovieID :       33, Number rated :    14, Predict rating : 3.6591
#   3.41%  UserID :      292, MovieID :       33, Number rated :    14, Predict rating : 3.6123
#   3.43%  UserID :      307, MovieID :       33, Number rated :    14, Predict rating : 3.6376
#   3.44%  UserID :      313, MovieID :       33, Number rated :    14, Predict rating : 3.6531
#   3.45%  UserID :      328, MovieID :       33, Number rated :    14, Predict rating : 3.6413
#   3.46%  UserID :      333, MovieID :       33, Number rated :    14, Predict rating : 3.6488
#   3.47%  UserID :      343, MovieID :       33, Number rated :    14, Predict rating : 3.6853
#   3.48%  UserID :      751, MovieID :       33, Number rated :    14, Predict rating : 3.6490
#   3.49%  UserID :      872, MovieID :       33, Number rated :    14, Predict rating : 3.6091
#   3.50%  UserID :      895, MovieID :       33, Number rated :    14, Predict rating : 3.7076
#   3.51%  UserID :      242, MovieID :       34, Number rated :    10, Predict rating : 3.5982
#   3.52%  UserID :      245, MovieID :       34, Number rated :    10, Predict rating : 3.0884
#   3.53%  UserID :      259, MovieID :       34, Number rated :    10, Predict rating : 3.0936
#   3.54%  UserID :      286, MovieID :       34, Number rated :    10, Predict rating : 3.1484
#   3.55%  UserID :      299, MovieID :       34, Number rated :    10, Predict rating : 3.5014
#   3.56%  UserID :      310, MovieID :       34, Number rated :    10, Predict rating : 3.4465
#   3.57%  UserID :      312, MovieID :       34, Number rated :    10, Predict rating : 3.4316
#   3.58%  UserID :      329, MovieID :       34, Number rated :    10, Predict rating : 3.5567
#   3.59%  UserID :      332, MovieID :       34, Number rated :    10, Predict rating : 3.3161
#   3.61%  UserID :      690, MovieID :       34, Number rated :    10, Predict rating : 3.4948
#   3.62%  UserID :      242, MovieID :       35, Number rated :    15, Predict rating : 3.0874
#   3.63%  UserID :      243, MovieID :       35, Number rated :    15, Predict rating : 3.0891
#   3.64%  UserID :      259, MovieID :       35, Number rated :    15, Predict rating : 3.0607
#   3.65%  UserID :      261, MovieID :       35, Number rated :    15, Predict rating : 2.9448
#   3.66%  UserID :      322, MovieID :       35, Number rated :    15, Predict rating : 3.2015
#   3.67%  UserID :      332, MovieID :       35, Number rated :    15, Predict rating : 3.1208
#   3.68%  UserID :      680, MovieID :       35, Number rated :    15, Predict rating : 3.0087
#   3.69%  UserID :      877, MovieID :       35, Number rated :    15, Predict rating : 3.1291
#   3.70%  UserID :      881, MovieID :       35, Number rated :    15, Predict rating : 3.0376
#   3.71%  UserID :     1025, MovieID :       35, Number rated :    15, Predict rating : 3.0430
#   3.72%  UserID :      268, MovieID :       36, Number rated :    10, Predict rating : 3.8030
#   3.73%  UserID :      269, MovieID :       36, Number rated :    10, Predict rating : 3.6822
#   3.74%  UserID :      307, MovieID :       36, Number rated :    10, Predict rating : 3.8019
#   3.75%  UserID :      319, MovieID :       36, Number rated :    10, Predict rating : 3.6550
#   3.76%  UserID :      339, MovieID :       36, Number rated :    10, Predict rating : 3.7966
#   3.78%  UserID :      682, MovieID :       36, Number rated :    10, Predict rating : 3.9727
#   3.79%  UserID :      748, MovieID :       36, Number rated :    10, Predict rating : 3.8477
#   3.80%  UserID :      882, MovieID :       36, Number rated :    10, Predict rating : 3.5848
#   3.81%  UserID :      883, MovieID :       36, Number rated :    10, Predict rating : 3.7356
#   3.82%  UserID :      885, MovieID :       36, Number rated :    10, Predict rating : 4.0085
#   3.83%  UserID :       55, MovieID :       37, Number rated :    47, Predict rating : 3.7691
#   3.84%  UserID :       56, MovieID :       37, Number rated :    47, Predict rating : 3.7684
#   3.85%  UserID :       79, MovieID :       37, Number rated :    47, Predict rating : 3.7452
#   3.86%  UserID :      117, MovieID :       37, Number rated :    47, Predict rating : 3.6698
#   3.87%  UserID :      183, MovieID :       37, Number rated :    47, Predict rating : 3.7753
#   3.88%  UserID :      222, MovieID :       37, Number rated :    47, Predict rating : 3.7016
#   3.89%  UserID :      288, MovieID :       37, Number rated :    47, Predict rating : 3.6958
#   3.90%  UserID :      403, MovieID :       37, Number rated :    47, Predict rating : 3.7394
#   3.91%  UserID :      540, MovieID :       37, Number rated :    47, Predict rating : 3.7089
#   3.92%  UserID :      685, MovieID :       37, Number rated :    47, Predict rating : 3.6335
#   3.93%  UserID :       95, MovieID :       38, Number rated :   111, Predict rating : 3.9066
#   3.94%  UserID :      139, MovieID :       38, Number rated :   111, Predict rating : 3.8117
#   3.96%  UserID :      153, MovieID :       38, Number rated :   111, Predict rating : 3.8365
#   3.97%  UserID :      161, MovieID :       38, Number rated :   111, Predict rating : 3.8525
#   3.98%  UserID :      328, MovieID :       38, Number rated :   111, Predict rating : 3.8673
#   3.99%  UserID :      432, MovieID :       38, Number rated :   111, Predict rating : 3.8584
#   4.00%  UserID :      465, MovieID :       38, Number rated :   111, Predict rating : 3.9150
#   4.01%  UserID :      573, MovieID :       38, Number rated :   111, Predict rating : 3.6100
#   4.02%  UserID :      679, MovieID :       38, Number rated :   111, Predict rating : 3.7146
#   4.03%  UserID :      758, MovieID :       38, Number rated :   111, Predict rating : 3.6459
#   4.04%  UserID :      258, MovieID :       39, Number rated :    12, Predict rating : 3.8872
#   4.05%  UserID :      300, MovieID :       39, Number rated :    12, Predict rating : 3.8234
#   4.06%  UserID :      306, MovieID :       39, Number rated :    12, Predict rating : 3.8060
#   4.07%  UserID :      313, MovieID :       39, Number rated :    12, Predict rating : 3.7741
#   4.08%  UserID :      315, MovieID :       39, Number rated :    12, Predict rating : 3.6546
#   4.09%  UserID :      333, MovieID :       39, Number rated :    12, Predict rating : 3.8437
#   4.10%  UserID :      345, MovieID :       39, Number rated :    12, Predict rating : 3.7611
#   4.11%  UserID :      347, MovieID :       39, Number rated :    12, Predict rating : 3.6949
#   4.13%  UserID :      352, MovieID :       39, Number rated :    12, Predict rating : 3.6949
#   4.14%  UserID :      900, MovieID :       39, Number rated :    12, Predict rating : 3.7012
#   4.15%  UserID :      243, MovieID :       40, Number rated :    25, Predict rating : 2.7703
#   4.16%  UserID :      258, MovieID :       40, Number rated :    25, Predict rating : 2.7038
#   4.17%  UserID :      268, MovieID :       40, Number rated :    25, Predict rating : 2.7262
#   4.18%  UserID :      271, MovieID :       40, Number rated :    25, Predict rating : 2.6899
#   4.19%  UserID :      303, MovieID :       40, Number rated :    25, Predict rating : 2.7744
#   4.20%  UserID :      333, MovieID :       40, Number rated :    25, Predict rating : 2.7246
#   4.21%  UserID :      340, MovieID :       40, Number rated :    25, Predict rating : 2.7102
#   4.22%  UserID :      345, MovieID :       40, Number rated :    25, Predict rating : 2.7718
#   4.23%  UserID :      754, MovieID :       40, Number rated :    25, Predict rating : 2.7248
#   4.24%  UserID :      880, MovieID :       40, Number rated :    25, Predict rating : 2.6988
#   4.25%  UserID :       28, MovieID :       41, Number rated :    42, Predict rating : 3.8195
#   4.26%  UserID :       31, MovieID :       41, Number rated :    42, Predict rating : 3.8135
#   4.27%  UserID :       98, MovieID :       41, Number rated :    42, Predict rating : 3.8490
#   4.28%  UserID :      170, MovieID :       41, Number rated :    42, Predict rating : 3.8697
#   4.29%  UserID :      265, MovieID :       41, Number rated :    42, Predict rating : 3.8351
#   4.31%  UserID :      313, MovieID :       41, Number rated :    42, Predict rating : 3.7913
#   4.32%  UserID :      435, MovieID :       41, Number rated :    42, Predict rating : 3.8683
#   4.33%  UserID :      486, MovieID :       41, Number rated :    42, Predict rating : 3.8907
#   4.34%  UserID :      746, MovieID :       41, Number rated :    42, Predict rating : 3.8542
#   4.35%  UserID :      751, MovieID :       41, Number rated :    42, Predict rating : 3.8141
#   4.36%  UserID :       44, MovieID :       42, Number rated :   173, Predict rating : 3.8095
#   4.37%  UserID :       96, MovieID :       42, Number rated :   173, Predict rating : 3.8711
#   4.38%  UserID :      274, MovieID :       42, Number rated :   173, Predict rating : 3.8319
#   4.39%  UserID :      403, MovieID :       42, Number rated :   173, Predict rating : 3.8634
#   4.40%  UserID :      423, MovieID :       42, Number rated :   173, Predict rating : 3.8952
#   4.41%  UserID :      546, MovieID :       42, Number rated :   173, Predict rating : 3.8078
#   4.42%  UserID :      588, MovieID :       42, Number rated :   173, Predict rating : 3.8930
#   4.43%  UserID :      625, MovieID :       42, Number rated :   173, Predict rating : 3.8904
#   4.44%  UserID :      794, MovieID :       42, Number rated :   173, Predict rating : 3.8339
#   4.45%  UserID :     1028, MovieID :       42, Number rated :   173, Predict rating : 3.8075
#   4.46%  UserID :        5, MovieID :       43, Number rated :   211, Predict rating : 3.7488
#   4.48%  UserID :       14, MovieID :       43, Number rated :   211, Predict rating : 3.8620
#   4.49%  UserID :       40, MovieID :       43, Number rated :   211, Predict rating : 3.7532
#   4.50%  UserID :      120, MovieID :       43, Number rated :   211, Predict rating : 3.7245
#   4.51%  UserID :      137, MovieID :       43, Number rated :   211, Predict rating : 3.8472
#   4.52%  UserID :      151, MovieID :       43, Number rated :   211, Predict rating : 3.8142
#   4.53%  UserID :      203, MovieID :       43, Number rated :   211, Predict rating : 3.8259
#   4.54%  UserID :      204, MovieID :       43, Number rated :   211, Predict rating : 3.8378
#   4.55%  UserID :      323, MovieID :       43, Number rated :   211, Predict rating : 3.7940
#   4.56%  UserID :      815, MovieID :       43, Number rated :   211, Predict rating : 3.7732
#   4.57%  UserID :       15, MovieID :       44, Number rated :   141, Predict rating : 3.6567
#   4.58%  UserID :      195, MovieID :       44, Number rated :   141, Predict rating : 3.6900
#   4.59%  UserID :      240, MovieID :       44, Number rated :   141, Predict rating : 3.6312
#   4.60%  UserID :      258, MovieID :       44, Number rated :   141, Predict rating : 3.6878
#   4.61%  UserID :      294, MovieID :       44, Number rated :   141, Predict rating : 3.6586
#   4.62%  UserID :      443, MovieID :       44, Number rated :   141, Predict rating : 3.6646
#   4.63%  UserID :      449, MovieID :       44, Number rated :   141, Predict rating : 3.6267
#   4.64%  UserID :      507, MovieID :       44, Number rated :   141, Predict rating : 3.7373
#   4.66%  UserID :      644, MovieID :       44, Number rated :   141, Predict rating : 3.7272
#   4.67%  UserID :      660, MovieID :       44, Number rated :   141, Predict rating : 3.6564
#   4.68%  UserID :       25, MovieID :       45, Number rated :    38, Predict rating : 3.7346
#   4.69%  UserID :      109, MovieID :       45, Number rated :    38, Predict rating : 3.6868
#   4.70%  UserID :      118, MovieID :       45, Number rated :    38, Predict rating : 3.6872
#   4.71%  UserID :      121, MovieID :       45, Number rated :    38, Predict rating : 3.7187
#   4.72%  UserID :      127, MovieID :       45, Number rated :    38, Predict rating : 3.8307
#   4.73%  UserID :      472, MovieID :       45, Number rated :    38, Predict rating : 3.6539
#   4.74%  UserID :      473, MovieID :       45, Number rated :    38, Predict rating : 3.7202
#   4.75%  UserID :      476, MovieID :       45, Number rated :    38, Predict rating : 3.6774
#   4.76%  UserID :      763, MovieID :       45, Number rated :    38, Predict rating : 3.6688
#   4.77%  UserID :     1061, MovieID :       45, Number rated :    38, Predict rating : 3.5544
#   4.78%  UserID :      127, MovieID :       46, Number rated :    17, Predict rating : 3.9381
#   4.79%  UserID :      151, MovieID :       46, Number rated :    17, Predict rating : 3.8902
#   4.80%  UserID :      181, MovieID :       46, Number rated :    17, Predict rating : 3.8876
#   4.81%  UserID :      288, MovieID :       46, Number rated :    17, Predict rating : 3.8798
#   4.83%  UserID :      307, MovieID :       46, Number rated :    17, Predict rating : 3.9565
#   4.84%  UserID :      313, MovieID :       46, Number rated :    17, Predict rating : 3.9191
#   4.85%  UserID :      328, MovieID :       46, Number rated :    17, Predict rating : 3.8498
#   4.86%  UserID :      333, MovieID :       46, Number rated :    17, Predict rating : 3.9014
#   4.87%  UserID :      690, MovieID :       46, Number rated :    17, Predict rating : 4.0127
#   4.88%  UserID :     1062, MovieID :       46, Number rated :    17, Predict rating : 4.4467
#   4.89%  UserID :      268, MovieID :       47, Number rated :    15, Predict rating : 3.6409
#   4.90%  UserID :      292, MovieID :       47, Number rated :    15, Predict rating : 3.5920
#   4.91%  UserID :      302, MovieID :       47, Number rated :    15, Predict rating : 3.6404
#   4.92%  UserID :      306, MovieID :       47, Number rated :    15, Predict rating : 3.7070
#   4.93%  UserID :      321, MovieID :       47, Number rated :    15, Predict rating : 3.6195
#   4.94%  UserID :      323, MovieID :       47, Number rated :    15, Predict rating : 3.4150
#   4.95%  UserID :      324, MovieID :       47, Number rated :    15, Predict rating : 3.6065
#   4.96%  UserID :      340, MovieID :       47, Number rated :    15, Predict rating : 3.6591
#   4.97%  UserID :      683, MovieID :       47, Number rated :    15, Predict rating : 3.5930
#   4.98%  UserID :      995, MovieID :       47, Number rated :    15, Predict rating : 3.7760
#   4.99%  UserID :      174, MovieID :       48, Number rated :    56, Predict rating : 3.9477
#   5.01%  UserID :      210, MovieID :       48, Number rated :    56, Predict rating : 3.9513
#   5.02%  UserID :      259, MovieID :       48, Number rated :    56, Predict rating : 3.7212
#   5.03%  UserID :      308, MovieID :       48, Number rated :    56, Predict rating : 3.4995
#   5.04%  UserID :      309, MovieID :       48, Number rated :    56, Predict rating : 3.8383
#   5.05%  UserID :      603, MovieID :       48, Number rated :    56, Predict rating : 3.9637
#   5.06%  UserID :      609, MovieID :       48, Number rated :    56, Predict rating : 3.9566
#   5.07%  UserID :      661, MovieID :       48, Number rated :    56, Predict rating : 3.9756
#   5.08%  UserID :      680, MovieID :       48, Number rated :    56, Predict rating : 3.5966
#   5.09%  UserID :      690, MovieID :       48, Number rated :    56, Predict rating : 3.6750
#   5.10%  UserID :       47, MovieID :       49, Number rated :   205, Predict rating : 2.8125
#   5.11%  UserID :       68, MovieID :       49, Number rated :   205, Predict rating : 2.5900
#   5.12%  UserID :      302, MovieID :       49, Number rated :   205, Predict rating : 2.7895
#   5.13%  UserID :      547, MovieID :       49, Number rated :   205, Predict rating : 2.8805
#   5.14%  UserID :      559, MovieID :       49, Number rated :   205, Predict rating : 2.6351
#   5.15%  UserID :      581, MovieID :       49, Number rated :   205, Predict rating : 2.6819
#   5.16%  UserID :      625, MovieID :       49, Number rated :   205, Predict rating : 2.5790
#   5.17%  UserID :      959, MovieID :       49, Number rated :   205, Predict rating : 2.7361
#   5.19%  UserID :      995, MovieID :       49, Number rated :   205, Predict rating : 2.8345
#   5.20%  UserID :     1003, MovieID :       49, Number rated :   205, Predict rating : 2.4184
#   5.21%  UserID :        9, MovieID :       50, Number rated :    14, Predict rating : 3.2909
#   5.22%  UserID :      123, MovieID :       50, Number rated :    14, Predict rating : 3.4313
#   5.23%  UserID :      125, MovieID :       50, Number rated :    14, Predict rating : 3.2606
#   5.24%  UserID :      246, MovieID :       50, Number rated :    14, Predict rating : 3.5334
#   5.25%  UserID :      253, MovieID :       50, Number rated :    14, Predict rating : 3.5228
#   5.26%  UserID :      286, MovieID :       50, Number rated :    14, Predict rating : 3.3960
#   5.27%  UserID :      325, MovieID :       50, Number rated :    14, Predict rating : 3.7558
#   5.28%  UserID :      475, MovieID :       50, Number rated :    14, Predict rating : 3.5077
#   5.29%  UserID :      823, MovieID :       50, Number rated :    14, Predict rating : 3.2835
#   5.30%  UserID :     1084, MovieID :       50, Number rated :    14, Predict rating : 3.3761
#   5.31%  UserID :       64, MovieID :       51, Number rated :    13, Predict rating : 3.8281
#   5.32%  UserID :       83, MovieID :       51, Number rated :    13, Predict rating : 3.8259
#   5.33%  UserID :      132, MovieID :       51, Number rated :    13, Predict rating : 3.7409
#   5.34%  UserID :      148, MovieID :       51, Number rated :    13, Predict rating : 3.9882
#   5.36%  UserID :      182, MovieID :       51, Number rated :    13, Predict rating : 3.7842
#   5.37%  UserID :      203, MovieID :       51, Number rated :    13, Predict rating : 3.7481
#   5.38%  UserID :      485, MovieID :       51, Number rated :    13, Predict rating : 3.6484
#   5.39%  UserID :      496, MovieID :       51, Number rated :    13, Predict rating : 3.7393
#   5.40%  UserID :      603, MovieID :       51, Number rated :    13, Predict rating : 3.6560
#   5.41%  UserID :      679, MovieID :       51, Number rated :    13, Predict rating : 3.8716
# ...
#  98.22%  UserID :       15, MovieID :      927, Number rated :   110, Predict rating : 3.7664
#  98.23%  UserID :       24, MovieID :      927, Number rated :   110, Predict rating : 3.7645
#  98.24%  UserID :      138, MovieID :      927, Number rated :   110, Predict rating : 3.6002
#  98.25%  UserID :      222, MovieID :      927, Number rated :   110, Predict rating : 3.8080
#  98.26%  UserID :      228, MovieID :      927, Number rated :   110, Predict rating : 3.7832
#  98.27%  UserID :      294, MovieID :      927, Number rated :   110, Predict rating : 3.7763
#  98.28%  UserID :      380, MovieID :      927, Number rated :   110, Predict rating : 3.7330
#  98.29%  UserID :      456, MovieID :      927, Number rated :   110, Predict rating : 3.6693
#  98.30%  UserID :      501, MovieID :      927, Number rated :   110, Predict rating : 3.7561
#  98.31%  UserID :        8, MovieID :      928, Number rated :    22, Predict rating : 4.6071
#  98.32%  UserID :       98, MovieID :      928, Number rated :    22, Predict rating : 4.5464
#  98.34%  UserID :      187, MovieID :      928, Number rated :    22, Predict rating : 4.5802
#  98.35%  UserID :      333, MovieID :      928, Number rated :    22, Predict rating : 4.4712
#  98.36%  UserID :      358, MovieID :      928, Number rated :    22, Predict rating : 4.4417
#  98.37%  UserID :      496, MovieID :      928, Number rated :    22, Predict rating : 4.5933
#  98.38%  UserID :      877, MovieID :      928, Number rated :    22, Predict rating : 4.5203
#  98.39%  UserID :      878, MovieID :      928, Number rated :    22, Predict rating : 4.5582
#  98.40%  UserID :     1007, MovieID :      928, Number rated :    22, Predict rating : 4.6189
#  98.41%  UserID :     1025, MovieID :      928, Number rated :    22, Predict rating : 4.4397
#  98.42%  UserID :       23, MovieID :      929, Number rated :    39, Predict rating : 3.7506
#  98.43%  UserID :       31, MovieID :      929, Number rated :    39, Predict rating : 3.6792
#  98.44%  UserID :       89, MovieID :      929, Number rated :    39, Predict rating : 3.7002
#  98.45%  UserID :      134, MovieID :      929, Number rated :    39, Predict rating : 3.7293
#  98.46%  UserID :      188, MovieID :      929, Number rated :    39, Predict rating : 3.7171
#  98.47%  UserID :      209, MovieID :      929, Number rated :    39, Predict rating : 3.6758
#  98.48%  UserID :      419, MovieID :      929, Number rated :    39, Predict rating : 3.6939
#  98.49%  UserID :      474, MovieID :      929, Number rated :    39, Predict rating : 3.7195
#  98.50%  UserID :      515, MovieID :      929, Number rated :    39, Predict rating : 3.7046
#  98.52%  UserID :      517, MovieID :      929, Number rated :    39, Predict rating : 3.7160
#  98.53%  UserID :        8, MovieID :      930, Number rated :    53, Predict rating : 2.9877
#  98.54%  UserID :      121, MovieID :      930, Number rated :    53, Predict rating : 2.9647
#  98.55%  UserID :      148, MovieID :      930, Number rated :    53, Predict rating : 2.9998
#  98.56%  UserID :      151, MovieID :      930, Number rated :    53, Predict rating : 2.9467
#  98.57%  UserID :      245, MovieID :      930, Number rated :    53, Predict rating : 3.0472
#  98.58%  UserID :      283, MovieID :      930, Number rated :    53, Predict rating : 3.1229
#  98.59%  UserID :      288, MovieID :      930, Number rated :    53, Predict rating : 2.9785
#  98.60%  UserID :      455, MovieID :      930, Number rated :    53, Predict rating : 2.8536
#  98.61%  UserID :      651, MovieID :      930, Number rated :    53, Predict rating : 2.9788
#  98.62%  UserID :      763, MovieID :      930, Number rated :    53, Predict rating : 2.8887
#  98.63%  UserID :       50, MovieID :      931, Number rated :    51, Predict rating : 3.8473
#  98.64%  UserID :      121, MovieID :      931, Number rated :    51, Predict rating : 3.7927
#  98.65%  UserID :      237, MovieID :      931, Number rated :    51, Predict rating : 3.8434
#  98.66%  UserID :      245, MovieID :      931, Number rated :    51, Predict rating : 3.8917
#  98.67%  UserID :      303, MovieID :      931, Number rated :    51, Predict rating : 3.9060
#  98.69%  UserID :      310, MovieID :      931, Number rated :    51, Predict rating : 3.9508
#  98.70%  UserID :      362, MovieID :      931, Number rated :    51, Predict rating : 3.8098
#  98.71%  UserID :      476, MovieID :      931, Number rated :    51, Predict rating : 3.7968
#  98.72%  UserID :      678, MovieID :      931, Number rated :    51, Predict rating : 3.8440
#  98.73%  UserID :     1152, MovieID :      931, Number rated :    51, Predict rating : 3.7475
#  98.74%  UserID :        7, MovieID :      932, Number rated :   231, Predict rating : 3.9103
#  98.75%  UserID :       55, MovieID :      932, Number rated :   231, Predict rating : 3.8545
#  98.76%  UserID :      105, MovieID :      932, Number rated :   231, Predict rating : 3.7702
#  98.77%  UserID :      135, MovieID :      932, Number rated :   231, Predict rating : 4.0422
#  98.78%  UserID :      176, MovieID :      932, Number rated :   231, Predict rating : 3.9283
#  98.79%  UserID :      285, MovieID :      932, Number rated :   231, Predict rating : 4.1260
#  98.80%  UserID :      435, MovieID :      932, Number rated :   231, Predict rating : 4.0705
#  98.81%  UserID :      504, MovieID :      932, Number rated :   231, Predict rating : 4.0981
#  98.82%  UserID :     1065, MovieID :      932, Number rated :   231, Predict rating : 4.0911
#  98.83%  UserID :     1204, MovieID :      932, Number rated :   231, Predict rating : 4.2245
#  98.84%  UserID :       28, MovieID :      933, Number rated :   174, Predict rating : 2.7567
#  98.85%  UserID :       64, MovieID :      933, Number rated :   174, Predict rating : 2.8035
#  98.87%  UserID :       98, MovieID :      933, Number rated :   174, Predict rating : 2.8095
#  98.88%  UserID :      156, MovieID :      933, Number rated :   174, Predict rating : 2.7577
#  98.89%  UserID :      187, MovieID :      933, Number rated :   174, Predict rating : 2.8378
#  98.90%  UserID :      317, MovieID :      933, Number rated :   174, Predict rating : 2.8232
#  98.91%  UserID :      447, MovieID :      933, Number rated :   174, Predict rating : 2.7089
#  98.92%  UserID :      523, MovieID :      933, Number rated :   174, Predict rating : 2.8582
#  98.93%  UserID :      577, MovieID :      933, Number rated :   174, Predict rating : 2.5015
#  98.94%  UserID :     1017, MovieID :      933, Number rated :   174, Predict rating : 2.7175
#  98.95%  UserID :       25, MovieID :      934, Number rated :   164, Predict rating : 3.7466
#  98.96%  UserID :       50, MovieID :      934, Number rated :   164, Predict rating : 3.7576
#  98.97%  UserID :      151, MovieID :      934, Number rated :   164, Predict rating : 3.7478
#  98.98%  UserID :      177, MovieID :      934, Number rated :   164, Predict rating : 3.7681
#  98.99%  UserID :      197, MovieID :      934, Number rated :   164, Predict rating : 3.7749
#  99.00%  UserID :      202, MovieID :      934, Number rated :   164, Predict rating : 3.7517
#  99.01%  UserID :      297, MovieID :      934, Number rated :   164, Predict rating : 3.7882
#  99.02%  UserID :      423, MovieID :      934, Number rated :   164, Predict rating : 3.7522
#  99.03%  UserID :      573, MovieID :      934, Number rated :   164, Predict rating : 3.7254
#  99.05%  UserID :     1425, MovieID :      934, Number rated :   164, Predict rating : 3.6805
#  99.06%  UserID :      100, MovieID :      935, Number rated :    29, Predict rating : 3.9786
#  99.07%  UserID :      121, MovieID :      935, Number rated :    29, Predict rating : 3.9984
#  99.08%  UserID :      127, MovieID :      935, Number rated :    29, Predict rating : 3.9833
#  99.09%  UserID :      257, MovieID :      935, Number rated :    29, Predict rating : 4.0022
#  99.10%  UserID :      284, MovieID :      935, Number rated :    29, Predict rating : 3.9974
#  99.11%  UserID :      471, MovieID :      935, Number rated :    29, Predict rating : 3.9938
#  99.12%  UserID :      476, MovieID :      935, Number rated :    29, Predict rating : 3.9750
#  99.13%  UserID :      717, MovieID :      935, Number rated :    29, Predict rating : 3.9768
#  99.14%  UserID :      742, MovieID :      935, Number rated :    29, Predict rating : 3.9739
#  99.15%  UserID :      846, MovieID :      935, Number rated :    29, Predict rating : 3.9428
#  99.16%  UserID :      106, MovieID :      936, Number rated :   132, Predict rating : 3.6001
#  99.17%  UserID :      111, MovieID :      936, Number rated :   132, Predict rating : 3.6676
#  99.18%  UserID :      236, MovieID :      936, Number rated :   132, Predict rating : 3.8368
#  99.19%  UserID :      281, MovieID :      936, Number rated :   132, Predict rating : 3.5993
#  99.20%  UserID :      285, MovieID :      936, Number rated :   132, Predict rating : 3.8842
#  99.22%  UserID :      298, MovieID :      936, Number rated :   132, Predict rating : 3.6409
#  99.23%  UserID :      340, MovieID :      936, Number rated :   132, Predict rating : 3.7820
#  99.24%  UserID :      818, MovieID :      936, Number rated :   132, Predict rating : 3.6948
#  99.25%  UserID :      952, MovieID :      936, Number rated :   132, Predict rating : 3.8771
#  99.26%  UserID :     1258, MovieID :      936, Number rated :   132, Predict rating : 3.6244
#  99.27%  UserID :        9, MovieID :      937, Number rated :    30, Predict rating : 3.3000
#  99.28%  UserID :      126, MovieID :      937, Number rated :    30, Predict rating : 3.2328
#  99.29%  UserID :      224, MovieID :      937, Number rated :    30, Predict rating : 3.4147
#  99.30%  UserID :      242, MovieID :      937, Number rated :    30, Predict rating : 3.3229
#  99.31%  UserID :      268, MovieID :      937, Number rated :    30, Predict rating : 3.2503
#  99.32%  UserID :      275, MovieID :      937, Number rated :    30, Predict rating : 3.3429
#  99.33%  UserID :      285, MovieID :      937, Number rated :    30, Predict rating : 3.3658
#  99.34%  UserID :      293, MovieID :      937, Number rated :    30, Predict rating : 3.2832
#  99.35%  UserID :      297, MovieID :      937, Number rated :    30, Predict rating : 3.3662
#  99.36%  UserID :      515, MovieID :      937, Number rated :    30, Predict rating : 3.3648
#  99.37%  UserID :      122, MovieID :      938, Number rated :    98, Predict rating : 3.3301
#  99.38%  UserID :      125, MovieID :      938, Number rated :    98, Predict rating : 3.3588
#  99.40%  UserID :      240, MovieID :      938, Number rated :    98, Predict rating : 3.3616
#  99.41%  UserID :      313, MovieID :      938, Number rated :    98, Predict rating : 3.4004
#  99.42%  UserID :      333, MovieID :      938, Number rated :    98, Predict rating : 3.3515
#  99.43%  UserID :      477, MovieID :      938, Number rated :    98, Predict rating : 3.3966
#  99.44%  UserID :      763, MovieID :      938, Number rated :    98, Predict rating : 3.3265
#  99.45%  UserID :      864, MovieID :      938, Number rated :    98, Predict rating : 3.3267
#  99.46%  UserID :      988, MovieID :      938, Number rated :    98, Predict rating : 3.3314
#  99.47%  UserID :     1033, MovieID :      938, Number rated :    98, Predict rating : 3.4175
#  99.48%  UserID :      106, MovieID :      939, Number rated :    39, Predict rating : 4.5041
#  99.49%  UserID :      121, MovieID :      939, Number rated :    39, Predict rating : 4.4943
#  99.50%  UserID :      258, MovieID :      939, Number rated :    39, Predict rating : 4.5165
#  99.51%  UserID :      409, MovieID :      939, Number rated :    39, Predict rating : 4.4813
#  99.52%  UserID :      476, MovieID :      939, Number rated :    39, Predict rating : 4.5660
#  99.53%  UserID :      689, MovieID :      939, Number rated :    39, Predict rating : 4.3190
#  99.54%  UserID :      931, MovieID :      939, Number rated :    39, Predict rating : 4.3712
#  99.55%  UserID :      993, MovieID :      939, Number rated :    39, Predict rating : 4.4756
#  99.57%  UserID :     1054, MovieID :      939, Number rated :    39, Predict rating : 4.4002
#  99.58%  UserID :     1190, MovieID :      939, Number rated :    39, Predict rating : 4.5089
#  99.59%  UserID :       14, MovieID :      940, Number rated :    97, Predict rating : 3.5492
#  99.60%  UserID :       66, MovieID :      940, Number rated :    97, Predict rating : 3.5576
#  99.61%  UserID :      193, MovieID :      940, Number rated :    97, Predict rating : 3.5584
#  99.62%  UserID :      205, MovieID :      940, Number rated :    97, Predict rating : 3.5849
#  99.63%  UserID :      272, MovieID :      940, Number rated :    97, Predict rating : 3.5753
#  99.64%  UserID :      289, MovieID :      940, Number rated :    97, Predict rating : 3.5454
#  99.65%  UserID :      315, MovieID :      940, Number rated :    97, Predict rating : 3.5371
#  99.66%  UserID :      568, MovieID :      940, Number rated :    97, Predict rating : 3.5841
#  99.67%  UserID :      655, MovieID :      940, Number rated :    97, Predict rating : 3.5594
#  99.68%  UserID :      873, MovieID :      940, Number rated :    97, Predict rating : 3.5183
#  99.69%  UserID :        7, MovieID :      941, Number rated :    12, Predict rating : 3.8332
#  99.70%  UserID :       15, MovieID :      941, Number rated :    12, Predict rating : 3.7898
#  99.71%  UserID :      117, MovieID :      941, Number rated :    12, Predict rating : 3.7730
#  99.72%  UserID :      124, MovieID :      941, Number rated :    12, Predict rating : 3.9642
#  99.73%  UserID :      147, MovieID :      941, Number rated :    12, Predict rating : 3.8210
#  99.75%  UserID :      181, MovieID :      941, Number rated :    12, Predict rating : 3.8084
#  99.76%  UserID :      257, MovieID :      941, Number rated :    12, Predict rating : 3.8134
#  99.77%  UserID :      258, MovieID :      941, Number rated :    12, Predict rating : 3.7876
#  99.78%  UserID :      475, MovieID :      941, Number rated :    12, Predict rating : 3.8687
#  99.79%  UserID :      993, MovieID :      941, Number rated :    12, Predict rating : 3.7966
#  99.80%  UserID :      117, MovieID :      942, Number rated :    69, Predict rating : 4.3787
#  99.81%  UserID :      200, MovieID :      942, Number rated :    69, Predict rating : 4.4169
#  99.82%  UserID :      261, MovieID :      942, Number rated :    69, Predict rating : 4.2224
#  99.83%  UserID :      323, MovieID :      942, Number rated :    69, Predict rating : 4.2139
#  99.84%  UserID :      423, MovieID :      942, Number rated :    69, Predict rating : 4.4427
#  99.85%  UserID :      427, MovieID :      942, Number rated :    69, Predict rating : 4.4623
#  99.86%  UserID :      487, MovieID :      942, Number rated :    69, Predict rating : 4.4964
#  99.87%  UserID :      584, MovieID :      942, Number rated :    69, Predict rating : 4.4710
#  99.88%  UserID :      604, MovieID :      942, Number rated :    69, Predict rating : 4.4685
#  99.89%  UserID :      615, MovieID :      942, Number rated :    69, Predict rating : 4.4819
#  99.90%  UserID :       11, MovieID :      943, Number rated :   158, Predict rating : 3.5258
#  99.92%  UserID :       58, MovieID :      943, Number rated :   158, Predict rating : 3.4956
#  99.93%  UserID :      111, MovieID :      943, Number rated :   158, Predict rating : 3.4946
#  99.94%  UserID :      186, MovieID :      943, Number rated :   158, Predict rating : 3.4772
#  99.95%  UserID :      215, MovieID :      943, Number rated :   158, Predict rating : 3.4548
#  99.96%  UserID :      232, MovieID :      943, Number rated :   158, Predict rating : 3.4230
#  99.97%  UserID :      356, MovieID :      943, Number rated :   158, Predict rating : 3.4305
#  99.98%  UserID :      570, MovieID :      943, Number rated :   158, Predict rating : 3.3702
#  99.99%  UserID :      808, MovieID :      943, Number rated :   158, Predict rating : 3.4016
# 100.00%  UserID :     1067, MovieID :      943, Number rated :   158, Predict rating : 3.6743
#
# Size of evaluate data :  9430
# Time : 574.3774647712708 seconds
# RMSE :  1.0205636267332547

# %%
print("Execute time : {:.4f} seconds".format(exec_time1))
print("RMSE on test data : {:.6f}".format(rmse_test_error1))
predicted_data1.head(10)
# Out:
# Execute time : 574.3775 seconds
# RMSE on test data : 1.020564
#    userId  movieId  rating  unix_timestamp  Predict rating
# 0       1       20       4       887431883        3.928550
# 1       1       33       4       878542699        3.697746
# 2       1       61       4       878542420        3.932885
# 3       1      117       3       874965739        3.709511
# 4       1      155       2       878542201        3.642885
# 5       1      160       4       875072547        3.800230
# 6       1      171       5       889751711        3.906974
# 7       1      189       3       888732928        3.838289
# 8       1      202       5       875072442        3.743903
# 9       1      265       4       878542441        3.723265

# %%
# Save predict rating
output_path1 = "./Output/Predict_Data-{}_Model-{}.csv".format(rs1.dataset_name, rs1.algo_name).replace(" ", "")
predicted_data1.to_csv(output_path1, index=False)

# %%
# Init instance
rs2 = CollaborativeFiltering(ratings_train2.iloc[:, :3].values, "ml-1m", uuCF=False)
rs2.fit()
# Out:
# Num users distinct :  3674
# Num items distinct :  6040
# Item-Item CF fit done

# %%
rs2.sparse_sim_matrix.shape
# Out:
# (3674, 6040)

# %%
# ids = [(5972, 593), (5952, 2401), (4933, 1805)]
# pred_ratings = rs.predict_rating_batch(ids).tolist()
# print("==================================================================================================")
# for (user_id, movie_id), pred_rating in zip(ids, pred_ratings):
#     true_rating = ratings_test[(ratings_test.userId == user_id) & (ratings_test.movieId == movie_id)].rating.values[0]
#     print("UserID : {:8d}, MovieID : {:8d} True rating : {:.1f}, Predict rating : {:.4f}".format(user_id, movie_id, true_rating, pred_rating))
# Out:
# Predicting 3 ratings ...
#  33.33%  UserID :      593, MovieID :     5972, Number rated :   350, Predict rating : 3.8119
#  66.67%  UserID :     2401, MovieID :     5952, Number rated :   107, Predict rating : 4.2706
# 100.00%  UserID :     1805, MovieID :     4933, Number rated :   247, Predict rating : 3.6016
# ==================================================================================================
# UserID :     5972, MovieID :      593 True rating : 5.0, Predict rating : 3.8119
# UserID :     5952, MovieID :     2401 True rating : 4.0, Predict rating : 4.2706
# UserID :     4933, MovieID :     1805 True rating : 2.0, Predict rating : 3.6016

# %%
predicted_data2, rmse_test_error2, exec_time2 = rs2.evaluate_model(ratings_test2.iloc[:1000])
# Out:
# Predicting 1000 ratings ...
#   0.10%  UserID :      593, MovieID :     5972, Number rated :   350, Predict rating : 3.8119
#   0.20%  UserID :     2401, MovieID :     5952, Number rated :   107, Predict rating : 4.2706
#   0.30%  UserID :     1805, MovieID :     4933, Number rated :   247, Predict rating : 3.6016
#   0.40%  UserID :      587, MovieID :     2181, Number rated :   731, Predict rating : 3.4101
#   0.50%  UserID :     1641, MovieID :     2513, Number rated :    51, Predict rating : 4.2181
#   0.60%  UserID :     2028, MovieID :     2146, Number rated :    84, Predict rating : 3.3154
#   0.70%  UserID :     1363, MovieID :     5111, Number rated :   628, Predict rating : 3.6214
#   0.80%  UserID :     1208, MovieID :      801, Number rated :   233, Predict rating : 3.7086
#   0.90%  UserID :     2028, MovieID :      929, Number rated :   283, Predict rating : 3.7929
#   1.00%  UserID :     1073, MovieID :     3152, Number rated :    23, Predict rating : 3.1253
#   1.10%  UserID :     1517, MovieID :     2907, Number rated :   691, Predict rating : 3.3367
#   1.20%  UserID :     2115, MovieID :     2968, Number rated :   142, Predict rating : 3.9250
#   1.30%  UserID :     2002, MovieID :       13, Number rated :    90, Predict rating : 3.3499
#   1.40%  UserID :      955, MovieID :     1883, Number rated :   344, Predict rating : 3.4000
#   1.50%  UserID :     3035, MovieID :     5749, Number rated :   331, Predict rating : 3.7207
#   1.60%  UserID :     1213, MovieID :     4735, Number rated :    94, Predict rating : 4.1449
#   1.70%  UserID :     2376, MovieID :     5333, Number rated :   659, Predict rating : 3.5425
#   1.80%  UserID :       36, MovieID :     1155, Number rated :   141, Predict rating : 3.3721
#   1.90%  UserID :     1955, MovieID :     2340, Number rated :   318, Predict rating : 4.4369
#   2.00%  UserID :      527, MovieID :     1131, Number rated :    78, Predict rating : 4.8364
#   2.10%  UserID :      898, MovieID :      534, Number rated :    79, Predict rating : 3.9407
#   2.20%  UserID :     1249, MovieID :     5857, Number rated :   164, Predict rating : 3.4428
#   2.30%  UserID :     2802, MovieID :     1335, Number rated :   248, Predict rating : 2.9714
#   2.40%  UserID :     1573, MovieID :     3904, Number rated :    88, Predict rating : 4.1017
#   2.50%  UserID :     2944, MovieID :     4884, Number rated :   310, Predict rating : 3.9515
#   2.60%  UserID :      832, MovieID :     3426, Number rated :    93, Predict rating : 3.7371
#   2.70%  UserID :     1136, MovieID :     5493, Number rated :   482, Predict rating : 3.5514
#   2.80%  UserID :       43, MovieID :     2794, Number rated :   111, Predict rating : 3.8478
#   2.90%  UserID :       39, MovieID :     3907, Number rated :    41, Predict rating : 3.7312
#   3.00%  UserID :      538, MovieID :     4562, Number rated :   238, Predict rating : 3.6711
#   3.10%  UserID :     2993, MovieID :     2472, Number rated :   234, Predict rating : 3.6394
#   3.20%  UserID :     1784, MovieID :     5482, Number rated :   296, Predict rating : 3.9732
#   3.30%  UserID :      541, MovieID :     2205, Number rated :   400, Predict rating : 3.1072
#   3.40%  UserID :     1307, MovieID :     2996, Number rated :   396, Predict rating : 3.3430
#   3.50%  UserID :     2381, MovieID :     4014, Number rated :   185, Predict rating : 3.7908
#   3.60%  UserID :      104, MovieID :     2097, Number rated :   136, Predict rating : 3.3519
#   3.70%  UserID :     1327, MovieID :     2457, Number rated :   404, Predict rating : 3.1541
#   3.80%  UserID :     2714, MovieID :     1105, Number rated :   120, Predict rating : 3.9206
#   3.90%  UserID :     1282, MovieID :     3957, Number rated :   285, Predict rating : 4.0118
#   4.00%  UserID :     2700, MovieID :      302, Number rated :   631, Predict rating : 3.1528
#   4.10%  UserID :      542, MovieID :     1812, Number rated :   535, Predict rating : 3.6915
#   4.20%  UserID :     2153, MovieID :     5455, Number rated :   113, Predict rating : 3.5995
#   4.30%  UserID :     2717, MovieID :     4575, Number rated :    91, Predict rating : 1.8256
#   4.40%  UserID :     2469, MovieID :      178, Number rated :    88, Predict rating : 3.9276
#   4.50%  UserID :     1968, MovieID :     5393, Number rated :   161, Predict rating : 3.2739
#   4.60%  UserID :     2521, MovieID :     1639, Number rated :   441, Predict rating : 3.6300
#   4.70%  UserID :     3311, MovieID :     4115, Number rated :   407, Predict rating : 3.8334
#   4.80%  UserID :      541, MovieID :     3051, Number rated :   322, Predict rating : 3.3860
#   4.90%  UserID :     3550, MovieID :     4510, Number rated :   976, Predict rating : 2.8621
#   5.00%  UserID :      719, MovieID :       48, Number rated :   485, Predict rating : 3.0183
#   5.10%  UserID :     1614, MovieID :     1354, Number rated :   535, Predict rating : 3.4839
#   5.20%  UserID :      371, MovieID :     3401, Number rated :   674, Predict rating : 3.0736
#   5.30%  UserID :     1251, MovieID :     4973, Number rated :   125, Predict rating : 3.6413
#   5.40%  UserID :     2881, MovieID :     4213, Number rated :   299, Predict rating : 4.0593
#   5.50%  UserID :     3500, MovieID :     1266, Number rated :   575, Predict rating : 3.4443
#   5.60%  UserID :      273, MovieID :     5878, Number rated :   492, Predict rating : 3.5675
#   5.70%  UserID :       50, MovieID :     4949, Number rated :    31, Predict rating : 4.3231
#   5.80%  UserID :     2366, MovieID :     1586, Number rated :   326, Predict rating : 4.5046
#   5.90%  UserID :     2208, MovieID :     3402, Number rated :   262, Predict rating : 3.9733
#   6.00%  UserID :       21, MovieID :     3922, Number rated :   136, Predict rating : 2.8970
#   6.10%  UserID :     3826, MovieID :      386, Number rated :   207, Predict rating : 3.2700
#   6.20%  UserID :     1191, MovieID :     4343, Number rated :   169, Predict rating : 3.2545
#   6.30%  UserID :     3174, MovieID :     5116, Number rated :    17, Predict rating : 4.3960
#   6.40%  UserID :     1334, MovieID :     1140, Number rated :   307, Predict rating : 3.7387
#   6.50%  UserID :     3623, MovieID :     2075, Number rated :    33, Predict rating : 3.3499
#   6.60%  UserID :     1370, MovieID :     4140, Number rated :   582, Predict rating : 3.2198
#   6.70%  UserID :       10, MovieID :      394, Number rated :    32, Predict rating : 3.4003
#   6.80%  UserID :     2971, MovieID :     2092, Number rated :   568, Predict rating : 3.6503
#   6.90%  UserID :     1957, MovieID :     1988, Number rated :   505, Predict rating : 3.6355
#   7.00%  UserID :     3608, MovieID :     2878, Number rated :   557, Predict rating : 3.6312
#   7.10%  UserID :     2726, MovieID :     1297, Number rated :   378, Predict rating : 3.6866
#   7.20%  UserID :      355, MovieID :     1980, Number rated :  1004, Predict rating : 3.3345
#   7.30%  UserID :      169, MovieID :     5492, Number rated :   295, Predict rating : 3.0537
#   7.40%  UserID :     3253, MovieID :     2251, Number rated :   332, Predict rating : 3.6928
#   7.50%  UserID :     1252, MovieID :     1896, Number rated :   164, Predict rating : 4.2218
#   7.60%  UserID :     2731, MovieID :     3371, Number rated :   387, Predict rating : 3.7021
#   7.70%  UserID :      781, MovieID :     2863, Number rated :    90, Predict rating : 3.5186
#   7.80%  UserID :      736, MovieID :     4808, Number rated :   758, Predict rating : 3.3331
#   7.90%  UserID :     1563, MovieID :     4088, Number rated :   324, Predict rating : 3.5287
#   8.00%  UserID :     3462, MovieID :     2760, Number rated :    52, Predict rating : 4.2786
#   8.10%  UserID :     3178, MovieID :     5777, Number rated :   105, Predict rating : 4.0023
#   8.20%  UserID :      592, MovieID :     1873, Number rated :   151, Predict rating : 3.5499
#   8.30%  UserID :     1810, MovieID :     2800, Number rated :    79, Predict rating : 3.6384
#   8.40%  UserID :       24, MovieID :     4609, Number rated :   207, Predict rating : 3.0137
#   8.50%  UserID :      737, MovieID :     3290, Number rated :   139, Predict rating : 2.7766
#   8.60%  UserID :      373, MovieID :      331, Number rated :   476, Predict rating : 3.9264
#   8.70%  UserID :     3424, MovieID :     1880, Number rated :   768, Predict rating : 3.5068
#   8.80%  UserID :     2762, MovieID :     5585, Number rated :   206, Predict rating : 3.6847
#   8.90%  UserID :     3840, MovieID :     4260, Number rated :   255, Predict rating : 3.0983
#   9.00%  UserID :      357, MovieID :      272, Number rated :   388, Predict rating : 3.8520
#   9.10%  UserID :       40, MovieID :       69, Number rated :    54, Predict rating : 4.1805
#   9.20%  UserID :     3624, MovieID :      712, Number rated :   224, Predict rating : 3.5459
#   9.30%  UserID :     2719, MovieID :     5854, Number rated :   320, Predict rating : 3.4828
#   9.40%  UserID :      923, MovieID :     4579, Number rated :   550, Predict rating : 3.8486
#   9.50%  UserID :     1988, MovieID :     4238, Number rated :   645, Predict rating : 3.2735
#   9.60%  UserID :      203, MovieID :     4077, Number rated :   179, Predict rating : 3.9162
#   9.70%  UserID :     1198, MovieID :     5468, Number rated :   300, Predict rating : 3.6120
#   9.80%  UserID :      529, MovieID :     1974, Number rated :   420, Predict rating : 3.7949
#   9.90%  UserID :      269, MovieID :     4430, Number rated :   222, Predict rating : 2.6473
#  10.00%  UserID :     2193, MovieID :     4458, Number rated :   333, Predict rating : 3.4121
#  10.10%  UserID :      164, MovieID :     4418, Number rated :   249, Predict rating : 3.8555
#  10.20%  UserID :      647, MovieID :     4425, Number rated :   729, Predict rating : 3.2946
#  10.30%  UserID :     3898, MovieID :     1715, Number rated :    31, Predict rating : 3.4854
#  10.40%  UserID :     1954, MovieID :     2876, Number rated :   153, Predict rating : 3.7727
#  10.50%  UserID :     1374, MovieID :     3953, Number rated :   186, Predict rating : 3.5846
#  10.60%  UserID :     3048, MovieID :     1422, Number rated :   567, Predict rating : 2.9785
#  10.70%  UserID :      481, MovieID :      518, Number rated :   204, Predict rating : 4.3277
#  10.80%  UserID :     1541, MovieID :     2203, Number rated :   415, Predict rating : 4.1114
#  10.90%  UserID :     2020, MovieID :     1396, Number rated :   144, Predict rating : 3.8093
#  11.00%  UserID :      377, MovieID :     2237, Number rated :   355, Predict rating : 3.9486
#  11.10%  UserID :     3066, MovieID :     3410, Number rated :   586, Predict rating : 3.1971
#  11.20%  UserID :     3108, MovieID :      339, Number rated :    92, Predict rating : 4.0641
#  11.30%  UserID :     2025, MovieID :      258, Number rated :   112, Predict rating : 3.6661
#  11.40%  UserID :     1370, MovieID :     4783, Number rated :    40, Predict rating : 3.5867
#  11.50%  UserID :     2076, MovieID :     4686, Number rated :    68, Predict rating : 4.4171
#  11.60%  UserID :     3753, MovieID :     5090, Number rated :   333, Predict rating : 4.1741
#  11.70%  UserID :     2571, MovieID :      888, Number rated :    61, Predict rating : 3.8738
#  11.80%  UserID :      592, MovieID :     4985, Number rated :   112, Predict rating : 3.8203
#  11.90%  UserID :     1193, MovieID :     5956, Number rated :   239, Predict rating : 3.4445
#  12.00%  UserID :     3201, MovieID :     4054, Number rated :   498, Predict rating : 3.8520
#  12.10%  UserID :     3596, MovieID :     5964, Number rated :   428, Predict rating : 3.7355
#  12.20%  UserID :     1994, MovieID :     3717, Number rated :   238, Predict rating : 3.7584
#  12.30%  UserID :       11, MovieID :     4124, Number rated :   254, Predict rating : 3.5640
#  12.40%  UserID :     1220, MovieID :     6040, Number rated :   285, Predict rating : 3.4435
#  12.50%  UserID :     2433, MovieID :     4375, Number rated :   266, Predict rating : 4.0787
#  12.60%  UserID :     3213, MovieID :      438, Number rated :   479, Predict rating : 3.5702
#  12.70%  UserID :       34, MovieID :     4164, Number rated :    26, Predict rating : 3.5775
#  12.80%  UserID :      507, MovieID :      192, Number rated :   409, Predict rating : 3.1682
#  12.90%  UserID :     2395, MovieID :     3922, Number rated :   136, Predict rating : 2.9635
#  13.00%  UserID :     1284, MovieID :     1023, Number rated :    30, Predict rating : 4.1629
#  13.10%  UserID :     3174, MovieID :     5121, Number rated :   129, Predict rating : 3.5819
#  13.20%  UserID :     1090, MovieID :     3592, Number rated :   287, Predict rating : 4.3696
#  13.30%  UserID :     2701, MovieID :     3607, Number rated :   208, Predict rating : 3.4411
#  13.40%  UserID :     1194, MovieID :     4140, Number rated :   582, Predict rating : 3.1884
#  13.50%  UserID :      913, MovieID :     3430, Number rated :   323, Predict rating : 3.5171
#  13.60%  UserID :      541, MovieID :     5212, Number rated :    34, Predict rating : 4.5263
#  13.70%  UserID :       25, MovieID :     5557, Number rated :   158, Predict rating : 4.2473
#  13.80%  UserID :     2551, MovieID :     4342, Number rated :   189, Predict rating : 4.3229
#  13.90%  UserID :     1148, MovieID :     1905, Number rated :    41, Predict rating : 4.2482
#  14.00%  UserID :      481, MovieID :     1988, Number rated :   505, Predict rating : 3.4963
#  14.10%  UserID :      969, MovieID :     3596, Number rated :   108, Predict rating : 4.7456
#  14.20%  UserID :     2355, MovieID :      696, Number rated :   309, Predict rating : 3.7690
#  14.30%  UserID :      593, MovieID :     5773, Number rated :    24, Predict rating : 3.8388
#  14.40%  UserID :      383, MovieID :     5689, Number rated :   400, Predict rating : 3.6733
#  14.50%  UserID :     2336, MovieID :     3892, Number rated :   379, Predict rating : 3.4887
#  14.60%  UserID :     2066, MovieID :     4136, Number rated :    30, Predict rating : 4.8203
#  14.70%  UserID :     1094, MovieID :     4472, Number rated :   378, Predict rating : 3.4844
#  14.80%  UserID :      933, MovieID :     3487, Number rated :   255, Predict rating : 3.6462
#  14.90%  UserID :     2268, MovieID :     2666, Number rated :    75, Predict rating : 3.8872
#  15.00%  UserID :     3507, MovieID :     1137, Number rated :   454, Predict rating : 3.9368
#  15.10%  UserID :     2797, MovieID :     2198, Number rated :    56, Predict rating : 3.7645
#  15.20%  UserID :      949, MovieID :     4835, Number rated :    58, Predict rating : 3.9817
#  15.30%  UserID :     2788, MovieID :      533, Number rated :   480, Predict rating : 3.5827
#  15.40%  UserID :      474, MovieID :      767, Number rated :   132, Predict rating : 4.1007
#  15.50%  UserID :     3814, MovieID :     2986, Number rated :   578, Predict rating : 3.5474
#  15.60%  UserID :     3623, MovieID :     3935, Number rated :   122, Predict rating : 3.5471
#  15.70%  UserID :     2108, MovieID :     4033, Number rated :   526, Predict rating : 3.9347
#  15.80%  UserID :     2006, MovieID :     2592, Number rated :   348, Predict rating : 3.6447
#  15.90%  UserID :     3897, MovieID :      368, Number rated :   243, Predict rating : 3.9188
#  16.00%  UserID :     2102, MovieID :     2920, Number rated :    19, Predict rating : 3.3287
#  16.10%  UserID :     3572, MovieID :     2181, Number rated :   731, Predict rating : 3.2171
#  16.20%  UserID :     3035, MovieID :     3292, Number rated :   751, Predict rating : 4.1110
#  16.30%  UserID :     1961, MovieID :     4989, Number rated :    61, Predict rating : 3.9847
#  16.40%  UserID :     1408, MovieID :      922, Number rated :   282, Predict rating : 3.6720
#  16.50%  UserID :      153, MovieID :     5827, Number rated :    87, Predict rating : 3.8024
#  16.60%  UserID :     2396, MovieID :     3347, Number rated :    32, Predict rating : 4.4346
#  16.70%  UserID :      148, MovieID :     3829, Number rated :   648, Predict rating : 3.1002
#  16.80%  UserID :     2247, MovieID :     3705, Number rated :   634, Predict rating : 3.7674
#  16.90%  UserID :     1270, MovieID :     5182, Number rated :   238, Predict rating : 3.9613
#  17.00%  UserID :     3507, MovieID :      702, Number rated :   384, Predict rating : 3.3577
#  17.10%  UserID :     1752, MovieID :     1564, Number rated :   100, Predict rating : 3.0435
#  17.20%  UserID :     1711, MovieID :     2918, Number rated :   298, Predict rating : 3.5791
#  17.30%  UserID :     1876, MovieID :     3610, Number rated :   557, Predict rating : 2.9065
#  17.40%  UserID :      454, MovieID :     4956, Number rated :   203, Predict rating : 3.8350
#  17.50%  UserID :     2735, MovieID :     5782, Number rated :    85, Predict rating : 3.6228
#  17.60%  UserID :     1244, MovieID :     1062, Number rated :   160, Predict rating : 4.5254
#  17.70%  UserID :       48, MovieID :     4265, Number rated :   175, Predict rating : 3.8661
#  17.80%  UserID :     1625, MovieID :     1605, Number rated :   792, Predict rating : 3.3807
#  17.90%  UserID :      585, MovieID :      553, Number rated :    56, Predict rating : 4.2644
#  18.00%  UserID :      512, MovieID :     1010, Number rated :   812, Predict rating : 2.4935
#  18.10%  UserID :      724, MovieID :      283, Number rated :    23, Predict rating : 4.9494
#  18.20%  UserID :     1396, MovieID :      462, Number rated :   125, Predict rating : 3.5887
#  18.30%  UserID :      906, MovieID :     1912, Number rated :   752, Predict rating : 2.6561
#  18.40%  UserID :     2725, MovieID :     5493, Number rated :   482, Predict rating : 3.5099
#  18.50%  UserID :     1374, MovieID :     1592, Number rated :   248, Predict rating : 3.6385
#  18.60%  UserID :     3185, MovieID :      604, Number rated :   222, Predict rating : 3.2032
#  18.70%  UserID :     2115, MovieID :     2403, Number rated :   137, Predict rating : 3.4578
#  18.80%  UserID :      160, MovieID :      148, Number rated :   495, Predict rating : 3.7532
#  18.90%  UserID :     2324, MovieID :     1001, Number rated :   299, Predict rating : 3.7999
#  19.00%  UserID :      318, MovieID :     4757, Number rated :    74, Predict rating : 4.3295
#  19.10%  UserID :     3543, MovieID :     1607, Number rated :   225, Predict rating : 3.2538
#  19.20%  UserID :     3255, MovieID :     1265, Number rated :   275, Predict rating : 3.2885
#  19.30%  UserID :     1594, MovieID :     3673, Number rated :   166, Predict rating : 3.9678
#  19.40%  UserID :     2067, MovieID :     1298, Number rated :   505, Predict rating : 3.9491
#  19.50%  UserID :     2794, MovieID :      669, Number rated :   330, Predict rating : 3.8665
#  19.60%  UserID :     2302, MovieID :     3353, Number rated :   187, Predict rating : 3.9641
#  19.70%  UserID :      222, MovieID :     5852, Number rated :   265, Predict rating : 3.4543
#  19.80%  UserID :     3022, MovieID :      656, Number rated :   148, Predict rating : 3.8940
#  19.90%  UserID :     2015, MovieID :     4064, Number rated :   784, Predict rating : 3.1247
#  20.00%  UserID :      529, MovieID :     2796, Number rated :   307, Predict rating : 2.6368
#  20.10%  UserID :      441, MovieID :     1960, Number rated :   175, Predict rating : 3.9240
#  20.20%  UserID :      586, MovieID :     3981, Number rated :   171, Predict rating : 3.5563
#  20.30%  UserID :     3114, MovieID :      281, Number rated :    90, Predict rating : 3.9785
#  20.40%  UserID :     1354, MovieID :     5317, Number rated :   424, Predict rating : 4.0890
#  20.50%  UserID :     1103, MovieID :      639, Number rated :   323, Predict rating : 3.7065
#  20.60%  UserID :     3261, MovieID :     2776, Number rated :   274, Predict rating : 4.0042
#  20.70%  UserID :     2948, MovieID :     4250, Number rated :   254, Predict rating : 3.9937
#  20.80%  UserID :     1019, MovieID :     4112, Number rated :   260, Predict rating : 4.1130
#  20.90%  UserID :     1235, MovieID :      343, Number rated :   233, Predict rating : 4.1758
#  21.00%  UserID :     3176, MovieID :     5029, Number rated :   130, Predict rating : 3.6144
#  21.10%  UserID :     1278, MovieID :     2941, Number rated :   285, Predict rating : 3.4967
#  21.20%  UserID :     2243, MovieID :      765, Number rated :   317, Predict rating : 3.6398
#  21.30%  UserID :     1970, MovieID :     3196, Number rated :   247, Predict rating : 3.2073
#  21.40%  UserID :     2183, MovieID :     1465, Number rated :   488, Predict rating : 3.8555
#  21.50%  UserID :     2691, MovieID :     1748, Number rated :   463, Predict rating : 3.4940
#  21.60%  UserID :     2985, MovieID :     5576, Number rated :   230, Predict rating : 3.9108
#  21.70%  UserID :     2363, MovieID :     4193, Number rated :   204, Predict rating : 3.6825
#  21.80%  UserID :      552, MovieID :      452, Number rated :   108, Predict rating : 4.4939
#  21.90%  UserID :     1234, MovieID :     4345, Number rated :   475, Predict rating : 3.6640
#  22.00%  UserID :     1527, MovieID :     5627, Number rated :   634, Predict rating : 3.0318
#  22.10%  UserID :     2303, MovieID :     4898, Number rated :   190, Predict rating : 4.2491
#  22.20%  UserID :     3388, MovieID :      392, Number rated :   390, Predict rating : 3.3893
#  22.30%  UserID :     3576, MovieID :      563, Number rated :   290, Predict rating : 2.7170
#  22.40%  UserID :     2599, MovieID :     2140, Number rated :   158, Predict rating : 3.9439
#  22.50%  UserID :     2872, MovieID :      858, Number rated :   156, Predict rating : 4.2420
#  22.60%  UserID :     3005, MovieID :     1489, Number rated :   403, Predict rating : 2.2903
#  22.70%  UserID :     2702, MovieID :     3323, Number rated :   105, Predict rating : 3.6642
#  22.80%  UserID :     1088, MovieID :      366, Number rated :   216, Predict rating : 4.0601
#  22.90%  UserID :     1270, MovieID :     5475, Number rated :   306, Predict rating : 4.0814
#  23.00%  UserID :     2995, MovieID :     1533, Number rated :    61, Predict rating : 3.8693
#  23.10%  UserID :     3048, MovieID :     5623, Number rated :   218, Predict rating : 3.7949
#  23.20%  UserID :     1380, MovieID :     1335, Number rated :   248, Predict rating : 3.0600
#  23.30%  UserID :     1225, MovieID :     2764, Number rated :   280, Predict rating : 4.2572
#  23.40%  UserID :     2710, MovieID :     4376, Number rated :    48, Predict rating : 3.9063
#  23.50%  UserID :     1960, MovieID :      970, Number rated :   443, Predict rating : 3.3502
#  23.60%  UserID :     3718, MovieID :     1712, Number rated :   416, Predict rating : 3.5559
#  23.70%  UserID :     2174, MovieID :     2447, Number rated :    43, Predict rating : 4.1914
#  23.80%  UserID :      350, MovieID :     4579, Number rated :   550, Predict rating : 3.6659
#  23.90%  UserID :     1810, MovieID :     4053, Number rated :   390, Predict rating : 3.5400
#  24.00%  UserID :     1391, MovieID :     4725, Number rated :   800, Predict rating : 3.1737
#  24.10%  UserID :      110, MovieID :     3760, Number rated :   250, Predict rating : 3.8687
#  24.20%  UserID :     2406, MovieID :     5232, Number rated :   106, Predict rating : 3.3005
#  24.30%  UserID :     3265, MovieID :      808, Number rated :   229, Predict rating : 3.5686
#  24.40%  UserID :      339, MovieID :     3695, Number rated :   243, Predict rating : 4.0211
#  24.50%  UserID :     1291, MovieID :     4482, Number rated :   633, Predict rating : 3.8102
#  24.60%  UserID :     1639, MovieID :     3470, Number rated :    64, Predict rating : 3.8180
#  24.70%  UserID :     1959, MovieID :      287, Number rated :    81, Predict rating : 3.6909
#  24.80%  UserID :     2589, MovieID :     1733, Number rated :   626, Predict rating : 3.4955
#  24.90%  UserID :     1231, MovieID :     1744, Number rated :   114, Predict rating : 4.1589
#  25.00%  UserID :     2502, MovieID :     4310, Number rated :   240, Predict rating : 3.9380
#  25.10%  UserID :     1752, MovieID :     4610, Number rated :   130, Predict rating : 3.1043
#  25.20%  UserID :      314, MovieID :     2841, Number rated :   352, Predict rating : 4.2485
#  25.30%  UserID :     3793, MovieID :      872, Number rated :    86, Predict rating : 3.6155
#  25.40%  UserID :     3004, MovieID :     1068, Number rated :   494, Predict rating : 3.7507
#  25.50%  UserID :     1183, MovieID :     1194, Number rated :   531, Predict rating : 3.4407
#  25.60%  UserID :     2028, MovieID :     2479, Number rated :    25, Predict rating : 3.9035
#  25.70%  UserID :     3094, MovieID :     4865, Number rated :   199, Predict rating : 3.3981
#  25.80%  UserID :     3039, MovieID :     1880, Number rated :   768, Predict rating : 3.3982
#  25.90%  UserID :     2916, MovieID :     3957, Number rated :   285, Predict rating : 3.9899
#  26.00%  UserID :     1282, MovieID :      525, Number rated :    32, Predict rating : 3.9666
#  26.10%  UserID :     3671, MovieID :     5009, Number rated :    50, Predict rating : 4.0687
#  26.20%  UserID :     2062, MovieID :     1812, Number rated :   535, Predict rating : 3.9234
#  26.30%  UserID :     3478, MovieID :      202, Number rated :   537, Predict rating : 3.3209
#  26.40%  UserID :     2001, MovieID :      293, Number rated :   260, Predict rating : 3.3436
#  26.50%  UserID :      339, MovieID :     2029, Number rated :   172, Predict rating : 3.1387
#  26.60%  UserID :     2644, MovieID :     2089, Number rated :    71, Predict rating : 3.9263
#  26.70%  UserID :      938, MovieID :     5716, Number rated :   172, Predict rating : 3.9184
#  26.80%  UserID :     3949, MovieID :     2895, Number rated :   402, Predict rating : 3.8536
#  26.90%  UserID :     1269, MovieID :     3329, Number rated :   115, Predict rating : 3.5320
#  27.00%  UserID :     1080, MovieID :      216, Number rated :   626, Predict rating : 3.2832
#  27.10%  UserID :     1883, MovieID :     3726, Number rated :   271, Predict rating : 3.5892
#  27.20%  UserID :      969, MovieID :     4649, Number rated :    25, Predict rating : 4.9566
#  27.30%  UserID :     1015, MovieID :     3867, Number rated :    36, Predict rating : 3.9983
#  27.40%  UserID :     2371, MovieID :      482, Number rated :   653, Predict rating : 3.3021
#  27.50%  UserID :       16, MovieID :        8, Number rated :   111, Predict rating : 3.9240
#  27.60%  UserID :     1272, MovieID :     1566, Number rated :    17, Predict rating : 3.7608
#  27.70%  UserID :     1278, MovieID :     2923, Number rated :    17, Predict rating : 4.0106
#  27.80%  UserID :     1967, MovieID :     5623, Number rated :   218, Predict rating : 3.9349
#  27.90%  UserID :     2762, MovieID :      516, Number rated :   237, Predict rating : 2.9933
#  28.00%  UserID :     2997, MovieID :     5870, Number rated :    28, Predict rating : 4.3096
#  28.10%  UserID :     2231, MovieID :     3837, Number rated :   155, Predict rating : 3.7592
#  28.20%  UserID :     3501, MovieID :     5553, Number rated :   221, Predict rating : 3.6055
#  28.30%  UserID :     1193, MovieID :     2168, Number rated :   303, Predict rating : 4.1111
#  28.40%  UserID :     2115, MovieID :     1938, Number rated :   151, Predict rating : 3.2138
#  28.50%  UserID :     3035, MovieID :     4627, Number rated :    81, Predict rating : 3.9159
#  28.60%  UserID :     3408, MovieID :     2307, Number rated :   122, Predict rating : 4.4554
#  28.70%  UserID :     3735, MovieID :     3018, Number rated :   486, Predict rating : 3.7631
#  28.80%  UserID :     2973, MovieID :      352, Number rated :   696, Predict rating : 3.7089
#  28.90%  UserID :     2352, MovieID :     2092, Number rated :   568, Predict rating : 3.6417
#  29.00%  UserID :      265, MovieID :     5226, Number rated :    68, Predict rating : 3.9564
#  29.10%  UserID :     1834, MovieID :     5911, Number rated :   147, Predict rating : 3.9498
#  29.20%  UserID :      466, MovieID :     2244, Number rated :   347, Predict rating : 3.4264
#  29.30%  UserID :     2772, MovieID :     1611, Number rated :   452, Predict rating : 3.5627
#  29.40%  UserID :     1222, MovieID :     3740, Number rated :    36, Predict rating : 4.3698
#  29.50%  UserID :     1243, MovieID :     2649, Number rated :   173, Predict rating : 3.2297
#  29.60%  UserID :     1276, MovieID :     1008, Number rated :    45, Predict rating : 3.9761
#  29.70%  UserID :      356, MovieID :     1870, Number rated :   128, Predict rating : 3.8233
#  29.80%  UserID :      356, MovieID :     1383, Number rated :   681, Predict rating : 3.4195
#  29.90%  UserID :     2621, MovieID :      955, Number rated :   265, Predict rating : 3.6185
#  30.00%  UserID :     2985, MovieID :     1776, Number rated :   330, Predict rating : 3.3054
#  30.10%  UserID :     2816, MovieID :     4021, Number rated :   611, Predict rating : 3.7461
#  30.20%  UserID :     3019, MovieID :     1465, Number rated :   488, Predict rating : 3.8314
#  30.30%  UserID :     2987, MovieID :     5650, Number rated :   242, Predict rating : 2.9557
#  30.40%  UserID :     1347, MovieID :     2114, Number rated :   120, Predict rating : 3.7455
#  30.50%  UserID :     1235, MovieID :     3825, Number rated :   395, Predict rating : 3.1152
#  30.60%  UserID :     3489, MovieID :     5827, Number rated :    87, Predict rating : 3.8009
#  30.70%  UserID :     1235, MovieID :      984, Number rated :   542, Predict rating : 3.6734
#  30.80%  UserID :     1678, MovieID :     5016, Number rated :    79, Predict rating : 3.0849
#  30.90%  UserID :      224, MovieID :     4962, Number rated :   174, Predict rating : 3.8352
#  31.00%  UserID :     3015, MovieID :      415, Number rated :   219, Predict rating : 3.8564
#  31.10%  UserID :     1270, MovieID :     3989, Number rated :   188, Predict rating : 4.1203
#  31.20%  UserID :      832, MovieID :     5015, Number rated :   540, Predict rating : 4.0267
#  31.30%  UserID :      587, MovieID :     1757, Number rated :   301, Predict rating : 3.6729
#  31.40%  UserID :     1198, MovieID :     1194, Number rated :   531, Predict rating : 3.3482
#  31.50%  UserID :       17, MovieID :      446, Number rated :    43, Predict rating : 4.8394
#  31.60%  UserID :     3175, MovieID :     3456, Number rated :    45, Predict rating : 4.6389
#  31.70%  UserID :     2352, MovieID :     5622, Number rated :    74, Predict rating : 4.0382
#  31.80%  UserID :      653, MovieID :     2665, Number rated :   654, Predict rating : 3.2702
#  31.90%  UserID :       85, MovieID :     5468, Number rated :   300, Predict rating : 3.7690
#  32.00%  UserID :     1173, MovieID :     3499, Number rated :   340, Predict rating : 3.6358
#  32.10%  UserID :     2333, MovieID :     4823, Number rated :   367, Predict rating : 3.5272
#  32.20%  UserID :     2872, MovieID :     3283, Number rated :   205, Predict rating : 3.7067
#  32.30%  UserID :      968, MovieID :     5568, Number rated :   282, Predict rating : 4.1250
#  32.40%  UserID :      708, MovieID :     4112, Number rated :   260, Predict rating : 4.0566
#  32.50%  UserID :      589, MovieID :     5932, Number rated :    14, Predict rating : 3.2876
#  32.60%  UserID :     2155, MovieID :     4227, Number rated :   984, Predict rating : 2.9298
#  32.70%  UserID :      282, MovieID :     1613, Number rated :   632, Predict rating : 3.5172
#  32.80%  UserID :     1629, MovieID :     1059, Number rated :   397, Predict rating : 2.8857
#  32.90%  UserID :     2688, MovieID :       83, Number rated :    73, Predict rating : 3.4302
#  33.00%  UserID :     3483, MovieID :     3087, Number rated :   236, Predict rating : 3.9866
#  33.10%  UserID :     3152, MovieID :     1896, Number rated :   164, Predict rating : 4.1972
#  33.20%  UserID :       47, MovieID :     5205, Number rated :   284, Predict rating : 3.5050
#  33.30%  UserID :      562, MovieID :     1924, Number rated :    73, Predict rating : 3.2352
#  33.40%  UserID :     3638, MovieID :     4458, Number rated :   333, Predict rating : 3.3951
#  33.50%  UserID :      608, MovieID :     1912, Number rated :   752, Predict rating : 2.6122
#  33.60%  UserID :     3451, MovieID :     2231, Number rated :   345, Predict rating : 3.7023
#  33.70%  UserID :     3863, MovieID :     3280, Number rated :   508, Predict rating : 2.8978
#  33.80%  UserID :     2699, MovieID :     1069, Number rated :   504, Predict rating : 2.9594
#  33.90%  UserID :     1544, MovieID :     3317, Number rated :    87, Predict rating : 3.9776
#  34.00%  UserID :     2160, MovieID :     3521, Number rated :   315, Predict rating : 3.8322
#  34.10%  UserID :     2605, MovieID :     2199, Number rated :   108, Predict rating : 3.0978
#  34.20%  UserID :      157, MovieID :     4088, Number rated :   324, Predict rating : 3.2425
#  34.30%  UserID :     2734, MovieID :      425, Number rated :   152, Predict rating : 3.7186
#  34.40%  UserID :      318, MovieID :     3933, Number rated :    19, Predict rating : 3.7952
#  34.50%  UserID :     3730, MovieID :       81, Number rated :    70, Predict rating : 4.5257
#  34.60%  UserID :     3274, MovieID :     1163, Number rated :    52, Predict rating : 3.6796
#  34.70%  UserID :     1306, MovieID :     3371, Number rated :   387, Predict rating : 3.4061
#  34.80%  UserID :     2408, MovieID :     5543, Number rated :   278, Predict rating : 3.5639
#  34.90%  UserID :     2087, MovieID :     1983, Number rated :   439, Predict rating : 4.2424
#  35.00%  UserID :      141, MovieID :     5555, Number rated :   434, Predict rating : 3.2969
#  35.10%  UserID :     3811, MovieID :     3814, Number rated :    28, Predict rating : 3.6776
#  35.20%  UserID :     1676, MovieID :     3457, Number rated :   120, Predict rating : 3.6224
#  35.30%  UserID :     1176, MovieID :     3301, Number rated :   250, Predict rating : 3.8836
#  35.40%  UserID :     1958, MovieID :     1632, Number rated :   600, Predict rating : 2.7675
#  35.50%  UserID :     3326, MovieID :       53, Number rated :   534, Predict rating : 4.2764
#  35.60%  UserID :      318, MovieID :     4066, Number rated :    81, Predict rating : 3.1723
#  35.70%  UserID :     2067, MovieID :      293, Number rated :   260, Predict rating : 3.7951
#  35.80%  UserID :      380, MovieID :     4389, Number rated :   104, Predict rating : 3.2227
#  35.90%  UserID :     2841, MovieID :      720, Number rated :   179, Predict rating : 3.0222
#  36.00%  UserID :     1282, MovieID :     3521, Number rated :   315, Predict rating : 3.8649
#  36.10%  UserID :     2815, MovieID :      744, Number rated :   242, Predict rating : 3.2469
#  36.20%  UserID :      164, MovieID :     4238, Number rated :   645, Predict rating : 3.6661
#  36.30%  UserID :      265, MovieID :      161, Number rated :   235, Predict rating : 4.4926
#  36.40%  UserID :     3328, MovieID :     1514, Number rated :   101, Predict rating : 3.9330
#  36.50%  UserID :     1639, MovieID :     2724, Number rated :   160, Predict rating : 3.9275
#  36.60%  UserID :     2919, MovieID :      180, Number rated :    48, Predict rating : 3.8967
#  36.70%  UserID :     1876, MovieID :     5016, Number rated :    79, Predict rating : 3.0592
#  36.80%  UserID :     2707, MovieID :     4064, Number rated :   784, Predict rating : 3.0888
#  36.90%  UserID :     1266, MovieID :      173, Number rated :   448, Predict rating : 4.0251
#  37.00%  UserID :      454, MovieID :     1284, Number rated :   405, Predict rating : 3.5127
#  37.10%  UserID :      610, MovieID :     4009, Number rated :   251, Predict rating : 2.9863
#  37.20%  UserID :     1252, MovieID :     1147, Number rated :   252, Predict rating : 3.6912
#  37.30%  UserID :     1587, MovieID :     3951, Number rated :   143, Predict rating : 3.5670
#  37.40%  UserID :     1747, MovieID :     3415, Number rated :   134, Predict rating : 4.0244
#  37.50%  UserID :      813, MovieID :     1527, Number rated :    74, Predict rating : 3.2247
#  37.60%  UserID :     3773, MovieID :     1340, Number rated :   645, Predict rating : 2.2211
#  37.70%  UserID :     3435, MovieID :     5026, Number rated :   722, Predict rating : 3.2047
#  37.80%  UserID :     2731, MovieID :     4167, Number rated :   369, Predict rating : 3.9731
#  37.90%  UserID :     1581, MovieID :     4386, Number rated :   712, Predict rating : 3.5383
#  38.00%  UserID :     1375, MovieID :     1837, Number rated :   632, Predict rating : 3.5494
#  38.10%  UserID :     2000, MovieID :     3661, Number rated :   105, Predict rating : 3.9832
#  38.20%  UserID :      708, MovieID :     5501, Number rated :   446, Predict rating : 3.2241
#  38.30%  UserID :     1573, MovieID :     2047, Number rated :   233, Predict rating : 3.5596
#  38.40%  UserID :       24, MovieID :     3929, Number rated :   497, Predict rating : 3.1490
#  38.50%  UserID :      344, MovieID :     5070, Number rated :   390, Predict rating : 3.5009
#  38.60%  UserID :     1371, MovieID :      905, Number rated :   103, Predict rating : 3.8691
#  38.70%  UserID :     2273, MovieID :      195, Number rated :   631, Predict rating : 3.7921
#  38.80%  UserID :     1293, MovieID :     3151, Number rated :   143, Predict rating : 4.2275
#  38.90%  UserID :      227, MovieID :      970, Number rated :   443, Predict rating : 3.1439
#  39.00%  UserID :     3615, MovieID :      957, Number rated :   264, Predict rating : 4.2973
#  39.10%  UserID :     1097, MovieID :     3936, Number rated :    29, Predict rating : 4.5830
#  39.20%  UserID :     3476, MovieID :     5597, Number rated :   163, Predict rating : 3.2992
#  39.30%  UserID :     3174, MovieID :     2692, Number rated :   106, Predict rating : 3.8299
#  39.40%  UserID :     1608, MovieID :     1882, Number rated :   187, Predict rating : 3.7285
#  39.50%  UserID :     2671, MovieID :     4480, Number rated :   383, Predict rating : 3.1057
#  39.60%  UserID :      112, MovieID :     1053, Number rated :   269, Predict rating : 3.5542
#  39.70%  UserID :     2571, MovieID :     2624, Number rated :   229, Predict rating : 4.1383
#  39.80%  UserID :      316, MovieID :     2015, Number rated :   730, Predict rating : 3.2915
#  39.90%  UserID :     3253, MovieID :     3942, Number rated :   476, Predict rating : 2.7277
#  40.00%  UserID :     1912, MovieID :     4957, Number rated :   597, Predict rating : 3.3073
#  40.10%  UserID :     2186, MovieID :     3610, Number rated :   557, Predict rating : 2.1071
#  40.20%  UserID :     2613, MovieID :     4227, Number rated :   984, Predict rating : 2.8615
#  40.30%  UserID :      180, MovieID :     5689, Number rated :   400, Predict rating : 3.6203
#  40.40%  UserID :      105, MovieID :     2109, Number rated :   590, Predict rating : 2.9709
#  40.50%  UserID :     3544, MovieID :     5830, Number rated :    37, Predict rating : 3.8895
#  40.60%  UserID :     1093, MovieID :     3825, Number rated :   395, Predict rating : 3.0125
#  40.70%  UserID :     3468, MovieID :     5517, Number rated :   255, Predict rating : 4.2617
#  40.80%  UserID :     3578, MovieID :     3093, Number rated :   141, Predict rating : 3.7927
#  40.90%  UserID :     3098, MovieID :     5890, Number rated :   258, Predict rating : 3.9310
#  41.00%  UserID :       11, MovieID :     3138, Number rated :   175, Predict rating : 3.4861
#  41.10%  UserID :     2907, MovieID :      355, Number rated :   332, Predict rating : 3.4494
#  41.20%  UserID :     2973, MovieID :     5779, Number rated :   317, Predict rating : 3.6226
#  41.30%  UserID :      353, MovieID :     1146, Number rated :   280, Predict rating : 2.9145
#  41.40%  UserID :     2568, MovieID :     5087, Number rated :   239, Predict rating : 3.4835
#  41.50%  UserID :     2816, MovieID :     4596, Number rated :   161, Predict rating : 3.2420
#  41.60%  UserID :     1729, MovieID :     2528, Number rated :    50, Predict rating : 3.2422
#  41.70%  UserID :     1380, MovieID :     2592, Number rated :   348, Predict rating : 3.6398
#  41.80%  UserID :     2115, MovieID :     1794, Number rated :   371, Predict rating : 2.6159
#  41.90%  UserID :     2808, MovieID :     1630, Number rated :    88, Predict rating : 2.1438
#  42.00%  UserID :      377, MovieID :      412, Number rated :   392, Predict rating : 4.4581
#  42.10%  UserID :     3198, MovieID :     5018, Number rated :   206, Predict rating : 4.0892
#  42.20%  UserID :     2662, MovieID :      892, Number rated :    24, Predict rating : 3.9104
#  42.30%  UserID :     1608, MovieID :     2010, Number rated :   587, Predict rating : 2.5868
#  42.40%  UserID :     2001, MovieID :     6010, Number rated :   254, Predict rating : 4.0532
#  42.50%  UserID :      357, MovieID :     4675, Number rated :   265, Predict rating : 3.7932
#  42.60%  UserID :     2424, MovieID :      223, Number rated :   205, Predict rating : 3.4720
#  42.70%  UserID :     2762, MovieID :      195, Number rated :   631, Predict rating : 3.9175
#  42.80%  UserID :      296, MovieID :     4390, Number rated :   216, Predict rating : 3.2658
#  42.90%  UserID :     1663, MovieID :     4375, Number rated :   266, Predict rating : 4.0658
#  43.00%  UserID :     2533, MovieID :     2880, Number rated :   230, Predict rating : 3.4225
#  43.10%  UserID :      111, MovieID :     5605, Number rated :   588, Predict rating : 3.1645
#  43.20%  UserID :      968, MovieID :     4169, Number rated :  1845, Predict rating : 3.6269
#  43.30%  UserID :     1132, MovieID :     5968, Number rated :    21, Predict rating : 4.4993
#  43.40%  UserID :     1120, MovieID :     5491, Number rated :   158, Predict rating : 3.7578
#  43.50%  UserID :      838, MovieID :     3364, Number rated :    85, Predict rating : 3.6015
#  43.60%  UserID :      594, MovieID :     2537, Number rated :   438, Predict rating : 3.2209
#  43.70%  UserID :     3639, MovieID :     5019, Number rated :   140, Predict rating : 3.2678
#  43.80%  UserID :     2353, MovieID :      949, Number rated :   289, Predict rating : 3.9413
#  43.90%  UserID :      608, MovieID :     5496, Number rated :    69, Predict rating : 3.7459
#  44.00%  UserID :     3684, MovieID :     4238, Number rated :   645, Predict rating : 3.5696
#  44.10%  UserID :      785, MovieID :     3471, Number rated :   669, Predict rating : 3.2467
#  44.20%  UserID :      924, MovieID :     5871, Number rated :    90, Predict rating : 4.2486
#  44.30%  UserID :     2918, MovieID :     3716, Number rated :   313, Predict rating : 3.7507
#  44.40%  UserID :     2042, MovieID :     5282, Number rated :   233, Predict rating : 2.9687
#  44.50%  UserID :      485, MovieID :     1902, Number rated :   206, Predict rating : 3.5868
#  44.60%  UserID :     2243, MovieID :     1696, Number rated :   240, Predict rating : 3.7473
#  44.70%  UserID :     2643, MovieID :     1958, Number rated :   682, Predict rating : 3.2649
#  44.80%  UserID :     2658, MovieID :     4354, Number rated :   522, Predict rating : 3.7523
#  44.90%  UserID :     3614, MovieID :     3080, Number rated :   429, Predict rating : 3.8531
#  45.00%  UserID :      479, MovieID :     4213, Number rated :   299, Predict rating : 4.0209
#  45.10%  UserID :     1077, MovieID :     3002, Number rated :   124, Predict rating : 4.3505
#  45.20%  UserID :     2707, MovieID :     3483, Number rated :   536, Predict rating : 3.8400
#  45.30%  UserID :     2410, MovieID :     5393, Number rated :   161, Predict rating : 3.1324
#  45.40%  UserID :     1563, MovieID :     3067, Number rated :   671, Predict rating : 3.8677
#  45.50%  UserID :     2018, MovieID :     4253, Number rated :   276, Predict rating : 3.5014
#  45.60%  UserID :     3179, MovieID :     3518, Number rated :   408, Predict rating : 3.8643
#  45.70%  UserID :     3948, MovieID :      606, Number rated :    23, Predict rating : 4.2075
#  45.80%  UserID :     3475, MovieID :     3248, Number rated :    68, Predict rating : 3.7839
#  45.90%  UserID :     1088, MovieID :     3032, Number rated :   805, Predict rating : 4.3649
#  46.00%  UserID :      485, MovieID :     1059, Number rated :   397, Predict rating : 2.8319
#  46.10%  UserID :     1091, MovieID :     1736, Number rated :   165, Predict rating : 3.2052
#  46.20%  UserID :      296, MovieID :     2750, Number rated :   160, Predict rating : 4.3085
#  46.30%  UserID :     3785, MovieID :     3077, Number rated :    63, Predict rating : 3.8437
#  46.40%  UserID :     1653, MovieID :     5708, Number rated :    79, Predict rating : 2.9153
#  46.50%  UserID :     2407, MovieID :     2411, Number rated :   257, Predict rating : 3.6374
#  46.60%  UserID :     1334, MovieID :     3224, Number rated :   885, Predict rating : 3.8109
#  46.70%  UserID :     2858, MovieID :     3311, Number rated :   725, Predict rating : 3.0639
#  46.80%  UserID :     2245, MovieID :      173, Number rated :   448, Predict rating : 3.9890
#  46.90%  UserID :     2125, MovieID :      118, Number rated :   178, Predict rating : 3.7994
#  47.00%  UserID :      356, MovieID :     1137, Number rated :   454, Predict rating : 3.8695
#  47.10%  UserID :     1772, MovieID :     5955, Number rated :   299, Predict rating : 3.5683
#  47.20%  UserID :     1411, MovieID :      453, Number rated :   319, Predict rating : 3.7740
#  47.30%  UserID :     1253, MovieID :     5806, Number rated :   170, Predict rating : 3.8556
#  47.40%  UserID :     2478, MovieID :     5634, Number rated :   245, Predict rating : 3.8393
#  47.50%  UserID :     1405, MovieID :     1168, Number rated :   184, Predict rating : 3.5258
#  47.60%  UserID :     3571, MovieID :     3542, Number rated :    17, Predict rating : 3.2795
#  47.70%  UserID :     1356, MovieID :     4489, Number rated :   341, Predict rating : 3.9699
#  47.80%  UserID :     3513, MovieID :     2656, Number rated :   114, Predict rating : 4.0628
#  47.90%  UserID :     1267, MovieID :     5269, Number rated :   240, Predict rating : 3.5572
#  48.00%  UserID :     2966, MovieID :      696, Number rated :   309, Predict rating : 3.8817
#  48.10%  UserID :     3358, MovieID :      549, Number rated :   941, Predict rating : 3.8814
#  48.20%  UserID :      610, MovieID :     4352, Number rated :   382, Predict rating : 3.6106
#  48.30%  UserID :     2723, MovieID :     1778, Number rated :   444, Predict rating : 3.6289
#  48.40%  UserID :     1376, MovieID :     3929, Number rated :   497, Predict rating : 3.1548
#  48.50%  UserID :     2252, MovieID :     4748, Number rated :   280, Predict rating : 4.1795
#  48.60%  UserID :     1297, MovieID :     2446, Number rated :   352, Predict rating : 3.9782
#  48.70%  UserID :     2004, MovieID :     4387, Number rated :   578, Predict rating : 3.0318
#  48.80%  UserID :     2762, MovieID :      839, Number rated :   650, Predict rating : 4.0797
#  48.90%  UserID :      613, MovieID :     4561, Number rated :    88, Predict rating : 4.0197
#  49.00%  UserID :     1732, MovieID :     1861, Number rated :   362, Predict rating : 3.4144
#  49.10%  UserID :     1017, MovieID :     5682, Number rated :   483, Predict rating : 3.8075
#  49.20%  UserID :     3451, MovieID :     4802, Number rated :   502, Predict rating : 4.1979
#  49.30%  UserID :     2700, MovieID :      729, Number rated :   113, Predict rating : 3.6867
#  49.40%  UserID :     1414, MovieID :     2063, Number rated :  1053, Predict rating : 3.0201
#  49.50%  UserID :     2959, MovieID :     2896, Number rated :   264, Predict rating : 3.6547
#  49.60%  UserID :     3615, MovieID :     2562, Number rated :   140, Predict rating : 3.9966
#  49.70%  UserID :      356, MovieID :     2125, Number rated :   182, Predict rating : 3.8895
#  49.80%  UserID :     1772, MovieID :     5535, Number rated :   144, Predict rating : 3.6680
#  49.90%  UserID :      377, MovieID :     5091, Number rated :   237, Predict rating : 3.7852
#  50.00%  UserID :     2641, MovieID :     3756, Number rated :   328, Predict rating : 3.9283
#  50.10%  UserID :     2329, MovieID :     3054, Number rated :   416, Predict rating : 3.4609
#  50.20%  UserID :      208, MovieID :     4773, Number rated :    80, Predict rating : 4.1561
#  50.30%  UserID :     1892, MovieID :     2962, Number rated :   487, Predict rating : 2.8541
#  50.40%  UserID :      318, MovieID :     3058, Number rated :   121, Predict rating : 3.8062
#  50.50%  UserID :     1454, MovieID :     5184, Number rated :   250, Predict rating : 4.0853
#  50.60%  UserID :     3914, MovieID :     1625, Number rated :    36, Predict rating : 3.5015
#  50.70%  UserID :     2683, MovieID :     1516, Number rated :   228, Predict rating : 3.2099
#  50.80%  UserID :      460, MovieID :     1690, Number rated :   117, Predict rating : 3.6128
#  50.90%  UserID :      377, MovieID :     5121, Number rated :   129, Predict rating : 3.5208
#  51.00%  UserID :     3836, MovieID :     3083, Number rated :    74, Predict rating : 3.9325
# ...
#  83.20%  UserID :     2747, MovieID :     5893, Number rated :   112, Predict rating : 3.1388
#  83.30%  UserID :      587, MovieID :     2136, Number rated :   120, Predict rating : 3.8848
#  83.40%  UserID :     3608, MovieID :      823, Number rated :    97, Predict rating : 3.9301
#  83.50%  UserID :     3751, MovieID :      938, Number rated :    26, Predict rating : 3.9993
#  83.60%  UserID :       11, MovieID :     5319, Number rated :   299, Predict rating : 3.8275
#  83.70%  UserID :      410, MovieID :     1434, Number rated :   220, Predict rating : 2.3538
#  83.80%  UserID :     1517, MovieID :     1340, Number rated :   645, Predict rating : 2.3770
#  83.90%  UserID :      592, MovieID :     1996, Number rated :   139, Predict rating : 4.0355
#  84.00%  UserID :     3091, MovieID :     5747, Number rated :   451, Predict rating : 3.6433
#  84.10%  UserID :     2922, MovieID :     1041, Number rated :    66, Predict rating : 4.3102
#  84.20%  UserID :     3394, MovieID :     2419, Number rated :   424, Predict rating : 3.3172
#  84.30%  UserID :     2643, MovieID :     1736, Number rated :   165, Predict rating : 3.1664
#  84.40%  UserID :      247, MovieID :     1320, Number rated :    89, Predict rating : 4.1572
#  84.50%  UserID :     3039, MovieID :     3724, Number rated :   455, Predict rating : 3.6029
#  84.60%  UserID :     2762, MovieID :     3119, Number rated :    71, Predict rating : 3.3130
#  84.70%  UserID :     1193, MovieID :     5079, Number rated :    46, Predict rating : 3.5446
#  84.80%  UserID :     3461, MovieID :     5530, Number rated :   515, Predict rating : 3.1409
#  84.90%  UserID :     2470, MovieID :     5614, Number rated :   673, Predict rating : 3.8156
#  85.00%  UserID :     1234, MovieID :     4917, Number rated :   187, Predict rating : 3.5406
#  85.10%  UserID :       31, MovieID :     5394, Number rated :   674, Predict rating : 3.3111
#  85.20%  UserID :     2001, MovieID :     1127, Number rated :   102, Predict rating : 3.4031
#  85.30%  UserID :     2880, MovieID :     2389, Number rated :   248, Predict rating : 3.9198
#  85.40%  UserID :     2971, MovieID :     2724, Number rated :   160, Predict rating : 3.8681
#  85.50%  UserID :     1171, MovieID :     1579, Number rated :   608, Predict rating : 3.5420
#  85.60%  UserID :     3176, MovieID :     5995, Number rated :   144, Predict rating : 4.0017
#  85.70%  UserID :     2355, MovieID :     2261, Number rated :   206, Predict rating : 3.5157
#  85.80%  UserID :     3738, MovieID :     1181, Number rated :  1229, Predict rating : 2.9274
#  85.90%  UserID :      468, MovieID :     1925, Number rated :   238, Predict rating : 3.6507
#  86.00%  UserID :     2455, MovieID :     1264, Number rated :   575, Predict rating : 3.6322
#  86.10%  UserID :     1249, MovieID :     1647, Number rated :   728, Predict rating : 3.4129
#  86.20%  UserID :     2701, MovieID :     3311, Number rated :   725, Predict rating : 2.9259
#  86.30%  UserID :     2014, MovieID :     5794, Number rated :   232, Predict rating : 3.7831
#  86.40%  UserID :     3033, MovieID :     4238, Number rated :   645, Predict rating : 3.5077
#  86.50%  UserID :     2040, MovieID :     4354, Number rated :   522, Predict rating : 3.5353
#  86.60%  UserID :     1084, MovieID :     3760, Number rated :   250, Predict rating : 3.8496
#  86.70%  UserID :      293, MovieID :     4277, Number rated :  1402, Predict rating : 4.2463
#  86.80%  UserID :     1198, MovieID :     2191, Number rated :    33, Predict rating : 3.3099
#  86.90%  UserID :      733, MovieID :     4473, Number rated :   334, Predict rating : 3.3990
#  87.00%  UserID :     2617, MovieID :     1680, Number rated :  1473, Predict rating : 3.5333
#  87.10%  UserID :     2790, MovieID :     2352, Number rated :    93, Predict rating : 2.6124
#  87.20%  UserID :     1393, MovieID :     4193, Number rated :   204, Predict rating : 3.6545
#  87.30%  UserID :     2296, MovieID :      770, Number rated :   610, Predict rating : 2.8942
#  87.40%  UserID :     2385, MovieID :     1764, Number rated :   478, Predict rating : 4.1063
#  87.50%  UserID :      356, MovieID :     2092, Number rated :   568, Predict rating : 3.5612
#  87.60%  UserID :     2353, MovieID :     2761, Number rated :   384, Predict rating : 3.4609
#  87.70%  UserID :     3147, MovieID :      175, Number rated :   250, Predict rating : 3.9714
#  87.80%  UserID :     2450, MovieID :     4085, Number rated :   677, Predict rating : 3.6639
#  87.90%  UserID :     1597, MovieID :     2592, Number rated :   348, Predict rating : 3.6288
#  88.00%  UserID :     3555, MovieID :     2245, Number rated :    40, Predict rating : 3.1808
#  88.10%  UserID :      351, MovieID :     5755, Number rated :   408, Predict rating : 3.5710
#  88.20%  UserID :     2526, MovieID :     4725, Number rated :   800, Predict rating : 3.1541
#  88.30%  UserID :     2804, MovieID :     4318, Number rated :   399, Predict rating : 3.9233
#  88.40%  UserID :     3053, MovieID :     5543, Number rated :   278, Predict rating : 3.6615
#  88.50%  UserID :       10, MovieID :     4279, Number rated :   391, Predict rating : 3.4053
#  88.60%  UserID :     2001, MovieID :     4021, Number rated :   611, Predict rating : 3.8362
#  88.70%  UserID :     1923, MovieID :     1899, Number rated :   625, Predict rating : 3.7769
#  88.80%  UserID :     1240, MovieID :     5879, Number rated :    42, Predict rating : 3.9235
#  88.90%  UserID :     3684, MovieID :      388, Number rated :    50, Predict rating : 3.9518
#  89.00%  UserID :     3386, MovieID :     1465, Number rated :   488, Predict rating : 3.7929
#  89.10%  UserID :     1923, MovieID :      685, Number rated :   110, Predict rating : 3.2490
#  89.20%  UserID :      367, MovieID :     1680, Number rated :  1473, Predict rating : 3.5835
#  89.30%  UserID :     2581, MovieID :     1377, Number rated :   418, Predict rating : 2.9084
#  89.40%  UserID :     2396, MovieID :     1802, Number rated :   158, Predict rating : 4.2131
#  89.50%  UserID :      695, MovieID :     2376, Number rated :   407, Predict rating : 3.3380
#  89.60%  UserID :     1276, MovieID :     3171, Number rated :    96, Predict rating : 4.0406
#  89.70%  UserID :      589, MovieID :     3064, Number rated :    33, Predict rating : 4.3861
#  89.80%  UserID :     3671, MovieID :     3283, Number rated :   205, Predict rating : 3.8008
#  89.90%  UserID :     2273, MovieID :     1606, Number rated :   158, Predict rating : 3.7958
#  90.00%  UserID :     2770, MovieID :     4593, Number rated :   236, Predict rating : 3.3092
#  90.10%  UserID :      289, MovieID :     4022, Number rated :   325, Predict rating : 3.1710
#  90.20%  UserID :     3254, MovieID :     2907, Number rated :   691, Predict rating : 3.3254
#  90.30%  UserID :     1253, MovieID :     5614, Number rated :   673, Predict rating : 3.8160
#  90.40%  UserID :     1994, MovieID :     1748, Number rated :   463, Predict rating : 3.4573
#  90.50%  UserID :      888, MovieID :     5361, Number rated :   138, Predict rating : 3.6523
#  90.60%  UserID :       94, MovieID :     1150, Number rated :  1035, Predict rating : 2.5138
#  90.70%  UserID :     2083, MovieID :     5394, Number rated :   674, Predict rating : 3.3662
#  90.80%  UserID :     2459, MovieID :     3771, Number rated :   373, Predict rating : 2.7731
#  90.90%  UserID :      252, MovieID :     4656, Number rated :   168, Predict rating : 3.8861
#  91.00%  UserID :      733, MovieID :     4095, Number rated :    51, Predict rating : 3.7638
#  91.10%  UserID :     3697, MovieID :     4272, Number rated :    91, Predict rating : 3.4627
#  91.20%  UserID :     2683, MovieID :     2922, Number rated :    54, Predict rating : 4.5936
#  91.30%  UserID :     1242, MovieID :     4647, Number rated :   696, Predict rating : 3.4498
#  91.40%  UserID :     3481, MovieID :     5706, Number rated :   130, Predict rating : 3.9815
#  91.50%  UserID :     1210, MovieID :     1507, Number rated :    96, Predict rating : 4.2217
#  91.60%  UserID :     2336, MovieID :      604, Number rated :   222, Predict rating : 3.1803
#  91.70%  UserID :     3852, MovieID :     1605, Number rated :   792, Predict rating : 3.4146
#  91.80%  UserID :     1203, MovieID :     3289, Number rated :    60, Predict rating : 4.1245
#  91.90%  UserID :     2364, MovieID :     5021, Number rated :   158, Predict rating : 3.1971
#  92.00%  UserID :     1732, MovieID :     5437, Number rated :   125, Predict rating : 3.6719
#  92.10%  UserID :     3877, MovieID :     3023, Number rated :    48, Predict rating : 3.5259
#  92.20%  UserID :     3694, MovieID :      709, Number rated :    73, Predict rating : 2.5269
#  92.30%  UserID :      653, MovieID :     3550, Number rated :   296, Predict rating : 3.4803
#  92.40%  UserID :     1320, MovieID :     1299, Number rated :   188, Predict rating : 3.9582
#  92.50%  UserID :     1320, MovieID :     1776, Number rated :   330, Predict rating : 3.3002
#  92.60%  UserID :     1955, MovieID :     1894, Number rated :   136, Predict rating : 4.3470
#  92.70%  UserID :     1584, MovieID :       42, Number rated :   177, Predict rating : 3.7748
#  92.80%  UserID :     3020, MovieID :     3910, Number rated :   212, Predict rating : 3.5209
#  92.90%  UserID :      593, MovieID :     1078, Number rated :    95, Predict rating : 3.9405
#  93.00%  UserID :     1876, MovieID :     5127, Number rated :    37, Predict rating : 3.1762
#  93.10%  UserID :     2001, MovieID :     2194, Number rated :    88, Predict rating : 2.8307
#  93.20%  UserID :     1409, MovieID :     5840, Number rated :   182, Predict rating : 3.6580
#  93.30%  UserID :     2023, MovieID :     2953, Number rated :    72, Predict rating : 3.3501
#  93.40%  UserID :     2231, MovieID :     3792, Number rated :   642, Predict rating : 3.7690
#  93.50%  UserID :      951, MovieID :     2185, Number rated :   246, Predict rating : 4.3976
#  93.60%  UserID :      888, MovieID :      869, Number rated :   684, Predict rating : 3.4606
#  93.70%  UserID :     1614, MovieID :     3292, Number rated :   751, Predict rating : 4.0071
#  93.80%  UserID :     1584, MovieID :     2164, Number rated :   377, Predict rating : 3.7085
#  93.90%  UserID :     2011, MovieID :     3336, Number rated :   546, Predict rating : 2.8461
#  94.00%  UserID :      247, MovieID :      673, Number rated :   333, Predict rating : 3.3501
#  94.10%  UserID :     1674, MovieID :     2485, Number rated :   187, Predict rating : 3.7944
#  94.20%  UserID :      608, MovieID :     4040, Number rated :   153, Predict rating : 3.4334
#  94.30%  UserID :     3707, MovieID :     5398, Number rated :    20, Predict rating : 4.0312
#  94.40%  UserID :      334, MovieID :     3483, Number rated :   536, Predict rating : 3.9017
#  94.50%  UserID :      733, MovieID :     2136, Number rated :   120, Predict rating : 3.9179
#  94.60%  UserID :     3247, MovieID :     2100, Number rated :   248, Predict rating : 3.7833
#  94.70%  UserID :     1345, MovieID :     2955, Number rated :   151, Predict rating : 3.4354
#  94.80%  UserID :     2745, MovieID :     1303, Number rated :   552, Predict rating : 3.4138
#  94.90%  UserID :     2357, MovieID :     4949, Number rated :    31, Predict rating : 4.4382
#  95.00%  UserID :     1201, MovieID :     1947, Number rated :   112, Predict rating : 4.0353
#  95.10%  UserID :      904, MovieID :     4531, Number rated :   197, Predict rating : 3.7614
#  95.20%  UserID :     1387, MovieID :     3430, Number rated :   323, Predict rating : 3.4647
#  95.30%  UserID :       58, MovieID :     1479, Number rated :    23, Predict rating : 4.0940
#  95.40%  UserID :      474, MovieID :     5333, Number rated :   659, Predict rating : 3.5853
#  95.50%  UserID :     2657, MovieID :     4186, Number rated :   496, Predict rating : 2.9117
#  95.60%  UserID :     2329, MovieID :     1040, Number rated :   211, Predict rating : 4.2572
#  95.70%  UserID :     1704, MovieID :     3927, Number rated :   114, Predict rating : 3.9917
#  95.80%  UserID :     3324, MovieID :     1319, Number rated :    21, Predict rating : 3.5398
#  95.90%  UserID :     2912, MovieID :     4327, Number rated :   126, Predict rating : 4.2141
#  96.00%  UserID :     2671, MovieID :     4162, Number rated :   105, Predict rating : 4.1096
#  96.10%  UserID :     2683, MovieID :     3314, Number rated :   266, Predict rating : 3.9859
#  96.20%  UserID :     3175, MovieID :     5060, Number rated :    57, Predict rating : 3.9676
#  96.30%  UserID :     2542, MovieID :      952, Number rated :   121, Predict rating : 4.0481
#  96.40%  UserID :     3285, MovieID :     3035, Number rated :    65, Predict rating : 3.8852
#  96.50%  UserID :     1190, MovieID :      593, Number rated :    89, Predict rating : 3.6647
#  96.60%  UserID :     2858, MovieID :     1442, Number rated :   125, Predict rating : 3.4842
#  96.70%  UserID :     1321, MovieID :      392, Number rated :   390, Predict rating : 3.5394
#  96.80%  UserID :     1347, MovieID :     5767, Number rated :   275, Predict rating : 3.6990
#  96.90%  UserID :      307, MovieID :     4478, Number rated :   360, Predict rating : 3.3685
#  97.00%  UserID :     2841, MovieID :      935, Number rated :   304, Predict rating : 3.4743
#  97.10%  UserID :     2132, MovieID :     1916, Number rated :   311, Predict rating : 4.0348
#  97.20%  UserID :     3873, MovieID :     1285, Number rated :   921, Predict rating : 4.0802
#  97.30%  UserID :     3298, MovieID :     2502, Number rated :    15, Predict rating : 3.8054
#  97.40%  UserID :     3791, MovieID :     5279, Number rated :    42, Predict rating : 3.6525
#  97.50%  UserID :     1385, MovieID :     4510, Number rated :   976, Predict rating : 2.8101
#  97.60%  UserID :       50, MovieID :     1043, Number rated :    30, Predict rating : 3.9146
#  97.70%  UserID :     3252, MovieID :     1912, Number rated :   752, Predict rating : 2.5111
#  97.80%  UserID :     1148, MovieID :     5090, Number rated :   333, Predict rating : 4.2031
#  97.90%  UserID :     1961, MovieID :     5682, Number rated :   483, Predict rating : 3.9339
#  98.00%  UserID :      595, MovieID :      889, Number rated :  1210, Predict rating : 2.9651
#  98.10%  UserID :     2948, MovieID :     1726, Number rated :   307, Predict rating : 2.5251
#  98.20%  UserID :     1200, MovieID :     3169, Number rated :   103, Predict rating : 4.0771
#  98.30%  UserID :     1066, MovieID :     4675, Number rated :   265, Predict rating : 3.9093
#  98.40%  UserID :      608, MovieID :     3465, Number rated :    46, Predict rating : 3.9737
#  98.50%  UserID :     1262, MovieID :      889, Number rated :  1210, Predict rating : 3.1357
#  98.60%  UserID :      165, MovieID :     2496, Number rated :   416, Predict rating : 2.9278
#  98.70%  UserID :     1073, MovieID :     3916, Number rated :   429, Predict rating : 3.9868
#  98.80%  UserID :     2108, MovieID :      660, Number rated :   561, Predict rating : 3.1231
#  98.90%  UserID :     2012, MovieID :     3512, Number rated :   327, Predict rating : 3.5885
#  99.00%  UserID :     2174, MovieID :     3095, Number rated :   140, Predict rating : 3.9149
#  99.10%  UserID :     1263, MovieID :     2476, Number rated :    49, Predict rating : 4.2710
#  99.20%  UserID :      839, MovieID :     4658, Number rated :   443, Predict rating : 2.3055
#  99.30%  UserID :     1391, MovieID :     1624, Number rated :   270, Predict rating : 2.9619
#  99.40%  UserID :     1777, MovieID :     1613, Number rated :   632, Predict rating : 3.5121
#  99.50%  UserID :     1345, MovieID :     5167, Number rated :   117, Predict rating : 4.1465
#  99.60%  UserID :     2624, MovieID :     1589, Number rated :    83, Predict rating : 3.8924
#  99.70%  UserID :     3421, MovieID :     4945, Number rated :   101, Predict rating : 3.8378
#  99.80%  UserID :     3723, MovieID :     4224, Number rated :   274, Predict rating : 3.9790
#  99.90%  UserID :     3266, MovieID :     2818, Number rated :   237, Predict rating : 3.6687
# 100.00%  UserID :      180, MovieID :     1051, Number rated :   682, Predict rating : 3.5796
#
# Size of evaluate data :  1000
# Time : 488.55619859695435 seconds
# RMSE :  1.0205944091535744

# %%
print("Execute time : {:.4f} seconds".format(exec_time2))
print("RMSE on test data : {:.6f}".format(rmse_test_error2))
predicted_data2.head(10)
# Out:
# Execute time : 1051.3008 seconds
# RMSE on test data : 1.009764
#    userId  movieId  rating  unix_timestamp  Predict rating
# 0    5972      593       5       956952291        4.361448
# 1    5952     2401       4       957145342        3.749669
# 2    4933     1805       2      1011684938        3.410706
# 3    2181      587       2       975634724        3.431049
# 4    2513     1641       5       974072036        3.872057
# 5    2146     2028       5       974623190        4.380173
# 6    5111     1363       2       962335163        3.025216
# 7     801     1208       5       975400546        4.245515
# 8     929     2028       5       975190707        4.352185
# 9    3152     1073       3      1019015734        3.881589
